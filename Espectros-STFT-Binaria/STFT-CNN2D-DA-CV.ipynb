# %% [markdown]
# ### Edgar Moises Hernandez-Gonzalez
# #### 16/05/20-26/05/20
# #### Clasificacion binaria de imagenes motoras en EEG con CNN-2D
# ##### Caracteristicas = Espectrogramas STFFT (3D)
# ##### Concatenacion vertical
# ##### Resize proporcional de 264x8
# ##### Data Augmentation
# ##### Validacion cruzada

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (cohen_kappa_score, confusion_matrix,
                             roc_auc_score, roc_curve)
from scipy.signal import spectrogram
import cv2
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
# para que este script funcione debe de decir 'channels_last', si dice 'channels_first' no sirve
K.image_data_format()
# Out:
# 'channels_last'

# %%
x_train = pd.read_csv("/content/drive/My Drive/BCI-IV-2a/Espectros-STFT-Binaria/MI-EEG-ID-A09T.csv", header=None)
x_test = pd.read_csv("/content/drive/My Drive/BCI-IV-2a/Espectros-STFT-Binaria/MI-EEG-ID-A09E.csv", header=None)
y_train = pd.read_csv("/content/drive/My Drive/BCI-IV-2a/Espectros-STFT-Binaria/Etiquetas-ID-A09T.csv", header=None)
y_test = pd.read_csv("/content/drive/My Drive/BCI-IV-2a/Espectros-STFT-Binaria/Etiquetas-ID-A09E.csv", header=None)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (144, 22000)
# (144, 22000)
# (144, 1)
# (144, 1)

# %%
x = pd.concat([x_train, x_test])
y = pd.concat([y_train, y_test])

# %%
print(x.shape)
print(y.shape)
# Out:
# (288, 22000)
# (288, 1)

# %%
# en caso de no tener el y_test se puede utilizar el x_test
n_samples = len(y)

print("n_samples:", n_samples)
# Out:
# n_samples: 288

# %%
# esto se podria calcular asi n_clases = len(np.unique(y)), la y puede ser train o test
n_classes = len(np.unique(y))

print("n_classes:", n_classes)
# Out:
# n_classes: 2

# %%
# codificar etiquetas con valores de 0 a nClases-1
# y = LabelEncoder().fit_transform(y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# las etiquetas en categorical para poder entrenar data augmentation
y_categorical = to_categorical(y)

# %%
#unir 22 canales y resize de tamaño proporcional
def unir_espectrogramas_vertical_resize(data):
  dim = (8, 264) #ancho, alto
  fs = 250
  datos = np.zeros((288,264,8))
  temporal = np.zeros((528,4))
  for i in range(data.shape[0]): #288 muestras
    for j in range(22): #22 canales
      sig = data.iloc[i, j*1000:(j+1)*1000]
      f, t, Sxx = spectrogram(sig, fs) #espectrograma de STFFT
      temporal[j*24:(j+1)*24, :] = Sxx[8:32, :]
    resized = cv2.resize(temporal, dim, interpolation=cv2.INTER_AREA)
    datos[i] = resized
    if i % 100 == 0: #esto solo es para ver como avanza
      print(i)
  return datos

# %%
#llamar a unir_espectrogramas_vertical_resize(data)
x = unir_espectrogramas_vertical_resize(x)
# Out:
# 0
# 100
# 200

# %%
print(x.shape)
# Out:
# (288, 264, 8)

# %%
print(np.max(x))
print(np.min(x))
print(np.mean(x))
# Out:
# 262.2188641748224
# 0.0008794545979459649
# 3.356582437939087

# %%
#convertir a float
x = x.astype('float32')

#escalar los valores en un rango de 0 a 1 (normalizar)
x /= np.ceil(np.max(x))

# %%
print(np.max(x))
print(np.min(x))
print(np.mean(x))
# Out:
# 0.99702996
# 3.343934e-06
# 0.012762672

# %%
#convertir de 3D a 4D
x = x.reshape((x.shape[0], x.shape[1], x.shape[2], 1))

print(x.shape)
# Out:
# (288, 264, 8, 1)

# %%
datagen = ImageDataGenerator(width_shift_range=0.25)

# %%
mc = ModelCheckpoint('/content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_ID_STFTDA09_CV.hdf5',
                     monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
skf = StratifiedKFold(n_splits = 10)

# %%
def CNN_2D():
  model = Sequential()
  model.add(Conv2D(16, (3,3), activation='relu', padding='same',
                   input_shape=x_train.shape[1:]))
  model.add(MaxPool2D((2,2)))
  model.add(Conv2D(16, (3,3), activation='relu', padding='same'))
  model.add(MaxPool2D((2,2)))
  model.add(Flatten())
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(n_classes, activation='softmax'))

  optimizer = Adam(lr=1e-4)
  model.compile(optimizer = optimizer,
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])
  return model

# %%
inicio = time.time()
array_loss = []
array_acc = []
array_kappa = []
array_auc = []
i = 0
for iTrain, jTest in skf.split(x, y):
  print("\nIteration:", i + 1)
  x_train, x_test = x[iTrain], x[jTest]
  y_train, y_test = y[iTrain], y[jTest]
  y_train_categorical, y_test_categorical = y_categorical[iTrain], y_categorical[jTest]

  model = CNN_2D()
  
  history = model.fit_generator(datagen.flow(x_train, y_train_categorical, batch_size=18),
                                steps_per_epoch=np.ceil(n_samples/18),
                                epochs=400,
                                validation_data=(x_test, y_test_categorical),
                                verbose=0, callbacks=[mc])
  
  test_loss, test_acc = model.evaluate(x_test, y_test_categorical, verbose=0)
  array_loss.append(test_loss)
  print("loss: ", test_loss)
  array_acc.append(test_acc)
  print("accuracy: ", test_acc)
    
  probabilidades = model.predict(x_test)
  y_pred = np.argmax(probabilidades, 1) #1=fila
    
  kappa = cohen_kappa_score(y_test, y_pred)
  array_kappa.append(kappa)
  print("kappa: ", kappa)
    
  matriz_confusion = confusion_matrix(y_test, y_pred)
  print("confusion matrix:\n", matriz_confusion)

  probabilidades = probabilidades[:, 1]
  auc = roc_auc_score(y_test, probabilidades)
  #fpr, tpr, thresholds = roc_curve(y_test, probabilidades)
  array_auc.append(auc)

  print("AUC", auc)
  #plt.plot(fpr, tpr)
  #plt.grid()
  #plt.xlabel('False Positive Rate')
  #plt.ylabel('True Positive Rate')
  #plt.show()

  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.grid()
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend(['train', 'test'])
  plt.show()
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.grid()
  plt.xlabel('Epochs')
  plt.ylabel('Cross-Entropy')
  plt.legend(['train', 'test'])
  plt.show()
  i += 1
print() 
print("Resultados:")
print("loss:", array_loss)
print("accuracy:", array_acc)
print("kappa:", array_kappa)
print("AUC:", array_auc)
fin = time.time()
print("Tiempo:", fin - inicio)
# Out:
# Iteration: 1
#
# Epoch 00001: val_accuracy improved from -inf to 0.51724, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_ID_STFTDA09_CV.hdf5
#
# Epoch 00002: val_accuracy did not improve from 0.51724
#
# Epoch 00003: val_accuracy improved from 0.51724 to 0.55172, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_ID_STFTDA09_CV.hdf5
#
# Epoch 00004: val_accuracy did not improve from 0.55172
#
# Epoch 00005: val_accuracy did not improve from 0.55172
#
# Epoch 00006: val_accuracy did not improve from 0.55172
#
# Epoch 00007: val_accuracy improved from 0.55172 to 0.58621, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_ID_STFTDA09_CV.hdf5
#
# Epoch 00008: val_accuracy improved from 0.58621 to 0.65517, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_ID_STFTDA09_CV.hdf5
#
# Epoch 00009: val_accuracy did not improve from 0.65517
#
# Epoch 00010: val_accuracy did not improve from 0.65517
#
# Epoch 00011: val_accuracy did not improve from 0.65517
#
# Epoch 00012: val_accuracy did not improve from 0.65517
#
# Epoch 00013: val_accuracy did not improve from 0.65517
#
# Epoch 00014: val_accuracy did not improve from 0.65517
#
# Epoch 00015: val_accuracy did not improve from 0.65517
#
# Epoch 00016: val_accuracy did not improve from 0.65517
#
# Epoch 00017: val_accuracy did not improve from 0.65517
#
# Epoch 00018: val_accuracy did not improve from 0.65517
#
# Epoch 00019: val_accuracy did not improve from 0.65517
#
# Epoch 00020: val_accuracy did not improve from 0.65517
#
# Epoch 00021: val_accuracy did not improve from 0.65517
#
# Epoch 00022: val_accuracy did not improve from 0.65517
#
# Epoch 00023: val_accuracy did not improve from 0.65517
#
# Epoch 00024: val_accuracy did not improve from 0.65517
#
# Epoch 00025: val_accuracy did not improve from 0.65517
#
# Epoch 00026: val_accuracy did not improve from 0.65517
#
# Epoch 00027: val_accuracy did not improve from 0.65517
#
# Epoch 00028: val_accuracy did not improve from 0.65517
#
# Epoch 00029: val_accuracy did not improve from 0.65517
#
# Epoch 00030: val_accuracy did not improve from 0.65517
#
# Epoch 00031: val_accuracy did not improve from 0.65517
#
# Epoch 00032: val_accuracy did not improve from 0.65517
#
# Epoch 00033: val_accuracy did not improve from 0.65517
#
# Epoch 00034: val_accuracy did not improve from 0.65517
#
# Epoch 00035: val_accuracy did not improve from 0.65517
#
# Epoch 00036: val_accuracy did not improve from 0.65517
#
# Epoch 00037: val_accuracy did not improve from 0.65517
#
# Epoch 00038: val_accuracy did not improve from 0.65517
#
# Epoch 00039: val_accuracy did not improve from 0.65517
#
# Epoch 00040: val_accuracy did not improve from 0.65517
#
# Epoch 00041: val_accuracy did not improve from 0.65517
#
# Epoch 00042: val_accuracy did not improve from 0.65517
#
# Epoch 00043: val_accuracy did not improve from 0.65517
#
# Epoch 00044: val_accuracy did not improve from 0.65517
#
# Epoch 00045: val_accuracy did not improve from 0.65517
#
# Epoch 00046: val_accuracy did not improve from 0.65517
#
# Epoch 00047: val_accuracy did not improve from 0.65517
#
# Epoch 00048: val_accuracy did not improve from 0.65517
#
# Epoch 00049: val_accuracy did not improve from 0.65517
#
# Epoch 00050: val_accuracy did not improve from 0.65517
#
# Epoch 00051: val_accuracy did not improve from 0.65517
#
# Epoch 00052: val_accuracy did not improve from 0.65517
#
# Epoch 00053: val_accuracy did not improve from 0.65517
#
# Epoch 00054: val_accuracy did not improve from 0.65517
#
# Epoch 00055: val_accuracy did not improve from 0.65517
#
# Epoch 00056: val_accuracy did not improve from 0.65517
#
# Epoch 00057: val_accuracy did not improve from 0.65517
#
# Epoch 00058: val_accuracy did not improve from 0.65517
#
# Epoch 00059: val_accuracy did not improve from 0.65517
#
# Epoch 00060: val_accuracy did not improve from 0.65517
#
# Epoch 00061: val_accuracy did not improve from 0.65517
#
# Epoch 00062: val_accuracy did not improve from 0.65517
#
# Epoch 00063: val_accuracy did not improve from 0.65517
#
# Epoch 00064: val_accuracy did not improve from 0.65517
#
# Epoch 00065: val_accuracy did not improve from 0.65517
#
# Epoch 00066: val_accuracy did not improve from 0.65517
#
# Epoch 00067: val_accuracy did not improve from 0.65517
#
# Epoch 00068: val_accuracy did not improve from 0.65517
#
# Epoch 00069: val_accuracy did not improve from 0.65517
#
# Epoch 00070: val_accuracy did not improve from 0.65517
#
# Epoch 00071: val_accuracy did not improve from 0.65517
#
# Epoch 00072: val_accuracy did not improve from 0.65517
#
# Epoch 00073: val_accuracy did not improve from 0.65517
#
# Epoch 00074: val_accuracy did not improve from 0.65517
#
# Epoch 00075: val_accuracy did not improve from 0.65517
#
# Epoch 00076: val_accuracy did not improve from 0.65517
#
# Epoch 00077: val_accuracy did not improve from 0.65517
#
# Epoch 00078: val_accuracy did not improve from 0.65517
#
# Epoch 00079: val_accuracy did not improve from 0.65517
#
# Epoch 00080: val_accuracy did not improve from 0.65517
#
# Epoch 00081: val_accuracy did not improve from 0.65517
#
# Epoch 00082: val_accuracy did not improve from 0.65517
#
# Epoch 00083: val_accuracy did not improve from 0.65517
#
# Epoch 00084: val_accuracy did not improve from 0.65517
#
# Epoch 00085: val_accuracy did not improve from 0.65517
#
# Epoch 00086: val_accuracy did not improve from 0.65517
#
# Epoch 00087: val_accuracy did not improve from 0.65517
#
# Epoch 00088: val_accuracy did not improve from 0.65517
#
# Epoch 00089: val_accuracy did not improve from 0.65517
#
# Epoch 00090: val_accuracy did not improve from 0.65517
#
# Epoch 00091: val_accuracy did not improve from 0.65517
#
# Epoch 00092: val_accuracy did not improve from 0.65517
#
# Epoch 00093: val_accuracy did not improve from 0.65517
#
# Epoch 00094: val_accuracy did not improve from 0.65517
#
# Epoch 00095: val_accuracy did not improve from 0.65517
#
# Epoch 00096: val_accuracy did not improve from 0.65517
#
# Epoch 00097: val_accuracy did not improve from 0.65517
#
# Epoch 00098: val_accuracy did not improve from 0.65517
#
# Epoch 00099: val_accuracy did not improve from 0.65517
#
# Epoch 00100: val_accuracy did not improve from 0.65517
#
# Epoch 00101: val_accuracy did not improve from 0.65517
#
# Epoch 00102: val_accuracy did not improve from 0.65517
#
# Epoch 00103: val_accuracy did not improve from 0.65517
#
# Epoch 00104: val_accuracy did not improve from 0.65517
#
# Epoch 00105: val_accuracy improved from 0.65517 to 0.68966, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_ID_STFTDA09_CV.hdf5
#
# Epoch 00106: val_accuracy did not improve from 0.68966
#
# Epoch 00107: val_accuracy did not improve from 0.68966
#
# Epoch 00108: val_accuracy did not improve from 0.68966
#
# Epoch 00109: val_accuracy did not improve from 0.68966
#
# Epoch 00110: val_accuracy did not improve from 0.68966
#
# Epoch 00111: val_accuracy did not improve from 0.68966
#
# Epoch 00112: val_accuracy did not improve from 0.68966
#
# Epoch 00113: val_accuracy did not improve from 0.68966
#
# Epoch 00114: val_accuracy did not improve from 0.68966
#
# Epoch 00115: val_accuracy did not improve from 0.68966
#
# Epoch 00116: val_accuracy did not improve from 0.68966
#
# Epoch 00117: val_accuracy did not improve from 0.68966
#
# Epoch 00118: val_accuracy did not improve from 0.68966
#
# Epoch 00119: val_accuracy did not improve from 0.68966
#
# Epoch 00120: val_accuracy did not improve from 0.68966
#
# Epoch 00121: val_accuracy did not improve from 0.68966
#
# Epoch 00122: val_accuracy did not improve from 0.68966
#
# Epoch 00123: val_accuracy did not improve from 0.68966
#
# Epoch 00124: val_accuracy did not improve from 0.68966
#
# Epoch 00125: val_accuracy did not improve from 0.68966
#
# Epoch 00126: val_accuracy did not improve from 0.68966
#
# Epoch 00127: val_accuracy did not improve from 0.68966
#
# Epoch 00128: val_accuracy did not improve from 0.68966
#
# Epoch 00129: val_accuracy did not improve from 0.68966
#
# Epoch 00130: val_accuracy did not improve from 0.68966
#
# Epoch 00131: val_accuracy did not improve from 0.68966
#
# Epoch 00132: val_accuracy did not improve from 0.68966
#
# Epoch 00133: val_accuracy did not improve from 0.68966
#
# Epoch 00134: val_accuracy did not improve from 0.68966
#
# Epoch 00135: val_accuracy did not improve from 0.68966
#
# Epoch 00136: val_accuracy did not improve from 0.68966
#
# Epoch 00137: val_accuracy did not improve from 0.68966
#
# Epoch 00138: val_accuracy improved from 0.68966 to 0.72414, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_ID_STFTDA09_CV.hdf5
#
# Epoch 00139: val_accuracy did not improve from 0.72414
#
# Epoch 00140: val_accuracy did not improve from 0.72414
#
# Epoch 00141: val_accuracy did not improve from 0.72414
#
# Epoch 00142: val_accuracy did not improve from 0.72414
#
# Epoch 00143: val_accuracy did not improve from 0.72414
#
# Epoch 00144: val_accuracy did not improve from 0.72414
#
# Epoch 00145: val_accuracy did not improve from 0.72414
#
# Epoch 00146: val_accuracy did not improve from 0.72414
#
# Epoch 00147: val_accuracy did not improve from 0.72414
#
# Epoch 00148: val_accuracy did not improve from 0.72414
#
# Epoch 00149: val_accuracy did not improve from 0.72414
#
# Epoch 00150: val_accuracy did not improve from 0.72414
#
# Epoch 00151: val_accuracy did not improve from 0.72414
#
# Epoch 00152: val_accuracy did not improve from 0.72414
#
# Epoch 00153: val_accuracy did not improve from 0.72414
#
# Epoch 00154: val_accuracy did not improve from 0.72414
#
# Epoch 00155: val_accuracy did not improve from 0.72414
#
# Epoch 00156: val_accuracy did not improve from 0.72414
#
# Epoch 00157: val_accuracy did not improve from 0.72414
#
# Epoch 00158: val_accuracy did not improve from 0.72414
#
# Epoch 00159: val_accuracy did not improve from 0.72414
#
# Epoch 00160: val_accuracy did not improve from 0.72414
#
# Epoch 00161: val_accuracy did not improve from 0.72414
#
# Epoch 00162: val_accuracy did not improve from 0.72414
#
# Epoch 00163: val_accuracy did not improve from 0.72414
#
# Epoch 00164: val_accuracy did not improve from 0.72414
#
# Epoch 00165: val_accuracy did not improve from 0.72414
#
# Epoch 00166: val_accuracy did not improve from 0.72414
#
# Epoch 00167: val_accuracy did not improve from 0.72414
#
# Epoch 00168: val_accuracy did not improve from 0.72414
#
# Epoch 00169: val_accuracy did not improve from 0.72414
#
# Epoch 00170: val_accuracy did not improve from 0.72414
#
# Epoch 00171: val_accuracy did not improve from 0.72414
#
# Epoch 00172: val_accuracy did not improve from 0.72414
#
# Epoch 00173: val_accuracy did not improve from 0.72414
#
# Epoch 00174: val_accuracy did not improve from 0.72414
#
# Epoch 00175: val_accuracy did not improve from 0.72414
#
# Epoch 00176: val_accuracy did not improve from 0.72414
#
# Epoch 00177: val_accuracy did not improve from 0.72414
#
# Epoch 00178: val_accuracy did not improve from 0.72414
#
# Epoch 00179: val_accuracy did not improve from 0.72414
#
# Epoch 00180: val_accuracy did not improve from 0.72414
#
# Epoch 00181: val_accuracy did not improve from 0.72414
#
# Epoch 00182: val_accuracy did not improve from 0.72414
#
# Epoch 00183: val_accuracy did not improve from 0.72414
#
# Epoch 00184: val_accuracy did not improve from 0.72414
#
# Epoch 00185: val_accuracy did not improve from 0.72414
#
# Epoch 00186: val_accuracy did not improve from 0.72414
#
# Epoch 00187: val_accuracy did not improve from 0.72414
#
# Epoch 00188: val_accuracy did not improve from 0.72414
#
# Epoch 00189: val_accuracy did not improve from 0.72414
#
# Epoch 00190: val_accuracy did not improve from 0.72414
#
# Epoch 00191: val_accuracy did not improve from 0.72414
#
# Epoch 00192: val_accuracy did not improve from 0.72414
#
# Epoch 00193: val_accuracy did not improve from 0.72414
#
# Epoch 00194: val_accuracy did not improve from 0.72414
#
# Epoch 00195: val_accuracy did not improve from 0.72414
#
# Epoch 00196: val_accuracy did not improve from 0.72414
#
# Epoch 00197: val_accuracy did not improve from 0.72414
#
# Epoch 00198: val_accuracy did not improve from 0.72414
#
# Epoch 00199: val_accuracy did not improve from 0.72414
#
# Epoch 00200: val_accuracy did not improve from 0.72414
#
# Epoch 00201: val_accuracy did not improve from 0.72414
#
# Epoch 00202: val_accuracy did not improve from 0.72414
#
# Epoch 00203: val_accuracy did not improve from 0.72414
#
# Epoch 00204: val_accuracy did not improve from 0.72414
#
# Epoch 00205: val_accuracy did not improve from 0.72414
#
# Epoch 00206: val_accuracy did not improve from 0.72414
#
# Epoch 00207: val_accuracy did not improve from 0.72414
#
# Epoch 00208: val_accuracy did not improve from 0.72414
#
# Epoch 00209: val_accuracy did not improve from 0.72414
#
# Epoch 00210: val_accuracy did not improve from 0.72414
#
# Epoch 00211: val_accuracy did not improve from 0.72414
#
# Epoch 00212: val_accuracy did not improve from 0.72414
#
# Epoch 00213: val_accuracy did not improve from 0.72414
#
# Epoch 00214: val_accuracy did not improve from 0.72414
#
# Epoch 00215: val_accuracy did not improve from 0.72414
#
# Epoch 00216: val_accuracy did not improve from 0.72414
#
# Epoch 00217: val_accuracy did not improve from 0.72414
#
# Epoch 00218: val_accuracy did not improve from 0.72414
#
# Epoch 00219: val_accuracy did not improve from 0.72414
#
# Epoch 00220: val_accuracy did not improve from 0.72414
#
# Epoch 00221: val_accuracy did not improve from 0.72414
#
# Epoch 00222: val_accuracy did not improve from 0.72414
#
# Epoch 00223: val_accuracy did not improve from 0.72414
#
# Epoch 00224: val_accuracy did not improve from 0.72414
#
# Epoch 00225: val_accuracy did not improve from 0.72414
#
# Epoch 00226: val_accuracy did not improve from 0.72414
#
# Epoch 00227: val_accuracy did not improve from 0.72414
#
# Epoch 00228: val_accuracy did not improve from 0.72414
#
# Epoch 00229: val_accuracy did not improve from 0.72414
#
# Epoch 00230: val_accuracy did not improve from 0.72414
#
# Epoch 00231: val_accuracy did not improve from 0.72414
#
# Epoch 00232: val_accuracy did not improve from 0.72414
#
# Epoch 00233: val_accuracy did not improve from 0.72414
#
# Epoch 00234: val_accuracy did not improve from 0.72414
#
# Epoch 00235: val_accuracy did not improve from 0.72414
#
# Epoch 00236: val_accuracy did not improve from 0.72414
#
# Epoch 00237: val_accuracy did not improve from 0.72414
#
# Epoch 00238: val_accuracy did not improve from 0.72414
#
# Epoch 00239: val_accuracy did not improve from 0.72414
#
# Epoch 00240: val_accuracy did not improve from 0.72414
#
# Epoch 00241: val_accuracy did not improve from 0.72414
#
# Epoch 00242: val_accuracy did not improve from 0.72414
#
# Epoch 00243: val_accuracy did not improve from 0.72414
#
# Epoch 00244: val_accuracy did not improve from 0.72414
#
# Epoch 00245: val_accuracy did not improve from 0.72414
#
# Epoch 00246: val_accuracy did not improve from 0.72414
#
# Epoch 00247: val_accuracy did not improve from 0.72414
#
# Epoch 00248: val_accuracy did not improve from 0.72414
#
# Epoch 00249: val_accuracy did not improve from 0.72414
#
# Epoch 00250: val_accuracy did not improve from 0.72414
#
# Epoch 00251: val_accuracy did not improve from 0.72414
#
# Epoch 00252: val_accuracy did not improve from 0.72414
#
# Epoch 00253: val_accuracy did not improve from 0.72414
#
# Epoch 00254: val_accuracy did not improve from 0.72414
#
# Epoch 00255: val_accuracy did not improve from 0.72414
#
# Epoch 00256: val_accuracy did not improve from 0.72414
#
# Epoch 00257: val_accuracy did not improve from 0.72414
#
# Epoch 00258: val_accuracy did not improve from 0.72414
#
# Epoch 00259: val_accuracy did not improve from 0.72414
#
# Epoch 00260: val_accuracy did not improve from 0.72414
#
# Epoch 00261: val_accuracy did not improve from 0.72414
#
# Epoch 00262: val_accuracy did not improve from 0.72414
#
# Epoch 00263: val_accuracy did not improve from 0.72414
#
# Epoch 00264: val_accuracy did not improve from 0.72414
#
# Epoch 00265: val_accuracy did not improve from 0.72414
#
# Epoch 00266: val_accuracy did not improve from 0.72414
#
# Epoch 00267: val_accuracy did not improve from 0.72414
#
# Epoch 00268: val_accuracy did not improve from 0.72414
#
# Epoch 00269: val_accuracy did not improve from 0.72414
#
# Epoch 00270: val_accuracy did not improve from 0.72414
#
# Epoch 00271: val_accuracy did not improve from 0.72414
#
# Epoch 00272: val_accuracy did not improve from 0.72414
#
# Epoch 00273: val_accuracy did not improve from 0.72414
#
# Epoch 00274: val_accuracy did not improve from 0.72414
#
# Epoch 00275: val_accuracy did not improve from 0.72414
#
# Epoch 00276: val_accuracy did not improve from 0.72414
#
# Epoch 00277: val_accuracy did not improve from 0.72414
#
# Epoch 00278: val_accuracy did not improve from 0.72414
#
# Epoch 00279: val_accuracy did not improve from 0.72414
#
# Epoch 00280: val_accuracy did not improve from 0.72414
#
# Epoch 00281: val_accuracy did not improve from 0.72414
#
# Epoch 00282: val_accuracy did not improve from 0.72414
#
# Epoch 00283: val_accuracy did not improve from 0.72414
#
# Epoch 00284: val_accuracy did not improve from 0.72414
#
# Epoch 00285: val_accuracy did not improve from 0.72414
#
# Epoch 00286: val_accuracy did not improve from 0.72414
#
# Epoch 00287: val_accuracy did not improve from 0.72414
#
# Epoch 00288: val_accuracy did not improve from 0.72414
#
# Epoch 00289: val_accuracy did not improve from 0.72414
#
# Epoch 00290: val_accuracy did not improve from 0.72414
#
# Epoch 00291: val_accuracy did not improve from 0.72414
#
# Epoch 00292: val_accuracy did not improve from 0.72414
#
# Epoch 00293: val_accuracy did not improve from 0.72414
#
# Epoch 00294: val_accuracy did not improve from 0.72414
#
# Epoch 00295: val_accuracy did not improve from 0.72414
#
# Epoch 00296: val_accuracy did not improve from 0.72414
#
# Epoch 00297: val_accuracy did not improve from 0.72414
#
# Epoch 00298: val_accuracy did not improve from 0.72414
#
# Epoch 00299: val_accuracy did not improve from 0.72414
#
# Epoch 00300: val_accuracy did not improve from 0.72414
#
# Epoch 00301: val_accuracy did not improve from 0.72414
#
# Epoch 00302: val_accuracy did not improve from 0.72414
#
# Epoch 00303: val_accuracy did not improve from 0.72414
#
# Epoch 00304: val_accuracy did not improve from 0.72414
#
# Epoch 00305: val_accuracy did not improve from 0.72414
#
# Epoch 00306: val_accuracy did not improve from 0.72414
#
# Epoch 00307: val_accuracy did not improve from 0.72414
#
# Epoch 00308: val_accuracy did not improve from 0.72414
#
# Epoch 00309: val_accuracy did not improve from 0.72414
#
# Epoch 00310: val_accuracy did not improve from 0.72414
#
# Epoch 00311: val_accuracy did not improve from 0.72414
#
# Epoch 00312: val_accuracy did not improve from 0.72414
#
# Epoch 00313: val_accuracy did not improve from 0.72414
#
# Epoch 00314: val_accuracy did not improve from 0.72414
#
# Epoch 00315: val_accuracy did not improve from 0.72414
#
# Epoch 00316: val_accuracy did not improve from 0.72414
#
# Epoch 00317: val_accuracy did not improve from 0.72414
#
# Epoch 00318: val_accuracy did not improve from 0.72414
#
# Epoch 00319: val_accuracy did not improve from 0.72414
#
# Epoch 00320: val_accuracy did not improve from 0.72414
#
# Epoch 00321: val_accuracy did not improve from 0.72414
#
# Epoch 00322: val_accuracy did not improve from 0.72414
#
# Epoch 00323: val_accuracy did not improve from 0.72414
#
# Epoch 00324: val_accuracy did not improve from 0.72414
#
# Epoch 00325: val_accuracy did not improve from 0.72414
#
# Epoch 00326: val_accuracy did not improve from 0.72414
#
# Epoch 00327: val_accuracy did not improve from 0.72414
#
# Epoch 00328: val_accuracy did not improve from 0.72414
#
# Epoch 00329: val_accuracy did not improve from 0.72414
#
# Epoch 00330: val_accuracy did not improve from 0.72414
#
# Epoch 00331: val_accuracy did not improve from 0.72414
#
# Epoch 00332: val_accuracy did not improve from 0.72414
#
# Epoch 00333: val_accuracy did not improve from 0.72414
#
# Epoch 00334: val_accuracy did not improve from 0.72414
#
# Epoch 00335: val_accuracy did not improve from 0.72414
#
# Epoch 00336: val_accuracy did not improve from 0.72414
#
# Epoch 00337: val_accuracy did not improve from 0.72414
#
# Epoch 00338: val_accuracy did not improve from 0.72414
#
# Epoch 00339: val_accuracy did not improve from 0.72414
#
# Epoch 00340: val_accuracy did not improve from 0.72414
#
# Epoch 00341: val_accuracy did not improve from 0.72414
#
# Epoch 00342: val_accuracy did not improve from 0.72414
#
# Epoch 00343: val_accuracy did not improve from 0.72414
#
# Epoch 00344: val_accuracy did not improve from 0.72414
#
# Epoch 00345: val_accuracy did not improve from 0.72414
#
# Epoch 00346: val_accuracy did not improve from 0.72414
#
# Epoch 00347: val_accuracy did not improve from 0.72414
#
# Epoch 00348: val_accuracy did not improve from 0.72414
#
# Epoch 00349: val_accuracy did not improve from 0.72414
#
# Epoch 00350: val_accuracy did not improve from 0.72414
#
# Epoch 00351: val_accuracy did not improve from 0.72414
#
# Epoch 00352: val_accuracy did not improve from 0.72414
#
# Epoch 00353: val_accuracy did not improve from 0.72414
#
# Epoch 00354: val_accuracy did not improve from 0.72414
#
# Epoch 00355: val_accuracy did not improve from 0.72414
#
# Epoch 00356: val_accuracy did not improve from 0.72414
#
# Epoch 00357: val_accuracy did not improve from 0.72414
#
# Epoch 00358: val_accuracy did not improve from 0.72414
#
# Epoch 00359: val_accuracy did not improve from 0.72414
#
# Epoch 00360: val_accuracy did not improve from 0.72414
#
# Epoch 00361: val_accuracy did not improve from 0.72414
#
# Epoch 00362: val_accuracy did not improve from 0.72414
#
# Epoch 00363: val_accuracy did not improve from 0.72414
#
# Epoch 00364: val_accuracy did not improve from 0.72414
#
# Epoch 00365: val_accuracy did not improve from 0.72414
#
# Epoch 00366: val_accuracy did not improve from 0.72414
#
# Epoch 00367: val_accuracy did not improve from 0.72414
#
# Epoch 00368: val_accuracy did not improve from 0.72414
#
# Epoch 00369: val_accuracy did not improve from 0.72414
#
# Epoch 00370: val_accuracy did not improve from 0.72414
#
# Epoch 00371: val_accuracy did not improve from 0.72414
#
# Epoch 00372: val_accuracy did not improve from 0.72414
#
# Epoch 00373: val_accuracy did not improve from 0.72414
#
# Epoch 00374: val_accuracy did not improve from 0.72414
#
# Epoch 00375: val_accuracy did not improve from 0.72414
#
# Epoch 00376: val_accuracy did not improve from 0.72414
#
# Epoch 00377: val_accuracy did not improve from 0.72414
#
# Epoch 00378: val_accuracy did not improve from 0.72414
#
# Epoch 00379: val_accuracy did not improve from 0.72414
#
# Epoch 00380: val_accuracy did not improve from 0.72414
#
# Epoch 00381: val_accuracy did not improve from 0.72414
#
# Epoch 00382: val_accuracy did not improve from 0.72414
#
# Epoch 00383: val_accuracy did not improve from 0.72414
#
# Epoch 00384: val_accuracy did not improve from 0.72414
#
# Epoch 00385: val_accuracy did not improve from 0.72414
#
# Epoch 00386: val_accuracy did not improve from 0.72414
#
# Epoch 00387: val_accuracy did not improve from 0.72414
#
# Epoch 00388: val_accuracy did not improve from 0.72414
#
# Epoch 00389: val_accuracy did not improve from 0.72414
#
# Epoch 00390: val_accuracy did not improve from 0.72414
#
# Epoch 00391: val_accuracy did not improve from 0.72414
#
# Epoch 00392: val_accuracy did not improve from 0.72414
#
# Epoch 00393: val_accuracy did not improve from 0.72414
#
# Epoch 00394: val_accuracy did not improve from 0.72414
#
# Epoch 00395: val_accuracy did not improve from 0.72414
#
# Epoch 00396: val_accuracy did not improve from 0.72414
#
# Epoch 00397: val_accuracy did not improve from 0.72414
#
# Epoch 00398: val_accuracy did not improve from 0.72414
#
# Epoch 00399: val_accuracy did not improve from 0.72414
#
# Epoch 00400: val_accuracy did not improve from 0.72414
# loss:  0.6956948041915894
# accuracy:  0.7241379022598267
# kappa:  0.4528301886792453
# confusion matrix:
#  [[12  2]
#  [ 6  9]]
# AUC 0.7714285714285715
# Iteration: 2
#
# Epoch 00001: val_accuracy did not improve from 0.72414
#
# Epoch 00002: val_accuracy did not improve from 0.72414
#
# Epoch 00003: val_accuracy did not improve from 0.72414
#
# Epoch 00004: val_accuracy did not improve from 0.72414
#
# Epoch 00005: val_accuracy did not improve from 0.72414
#
# Epoch 00006: val_accuracy did not improve from 0.72414
#
# Epoch 00007: val_accuracy did not improve from 0.72414
#
# Epoch 00008: val_accuracy did not improve from 0.72414
#
# Epoch 00009: val_accuracy did not improve from 0.72414
#
# Epoch 00010: val_accuracy did not improve from 0.72414
#
# Epoch 00011: val_accuracy improved from 0.72414 to 0.79310, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_ID_STFTDA09_CV.hdf5
#
# Epoch 00012: val_accuracy improved from 0.79310 to 0.82759, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_ID_STFTDA09_CV.hdf5
#
# Epoch 00013: val_accuracy did not improve from 0.82759
#
# Epoch 00014: val_accuracy did not improve from 0.82759
#
# Epoch 00015: val_accuracy did not improve from 0.82759
#
# Epoch 00016: val_accuracy did not improve from 0.82759
#
# Epoch 00017: val_accuracy did not improve from 0.82759
#
# Epoch 00018: val_accuracy did not improve from 0.82759
#
# Epoch 00019: val_accuracy did not improve from 0.82759
#
# Epoch 00020: val_accuracy did not improve from 0.82759
#
# Epoch 00021: val_accuracy did not improve from 0.82759
#
# Epoch 00022: val_accuracy did not improve from 0.82759
#
# Epoch 00023: val_accuracy did not improve from 0.82759
#
# Epoch 00024: val_accuracy did not improve from 0.82759
#
# Epoch 00025: val_accuracy did not improve from 0.82759
#
# Epoch 00026: val_accuracy did not improve from 0.82759
#
# Epoch 00027: val_accuracy did not improve from 0.82759
#
# Epoch 00028: val_accuracy did not improve from 0.82759
#
# Epoch 00029: val_accuracy did not improve from 0.82759
#
# Epoch 00030: val_accuracy did not improve from 0.82759
#
# Epoch 00031: val_accuracy did not improve from 0.82759
#
# Epoch 00032: val_accuracy did not improve from 0.82759
#
# Epoch 00033: val_accuracy did not improve from 0.82759
#
# Epoch 00034: val_accuracy did not improve from 0.82759
#
# Epoch 00035: val_accuracy did not improve from 0.82759
#
# Epoch 00036: val_accuracy did not improve from 0.82759
#
# Epoch 00037: val_accuracy did not improve from 0.82759
#
# Epoch 00038: val_accuracy did not improve from 0.82759
#
# Epoch 00039: val_accuracy did not improve from 0.82759
#
# Epoch 00040: val_accuracy did not improve from 0.82759
#
# Epoch 00041: val_accuracy did not improve from 0.82759
#
# Epoch 00042: val_accuracy did not improve from 0.82759
#
# Epoch 00043: val_accuracy did not improve from 0.82759
#
# Epoch 00044: val_accuracy did not improve from 0.82759
#
# Epoch 00045: val_accuracy did not improve from 0.82759
#
# Epoch 00046: val_accuracy did not improve from 0.82759
#
# Epoch 00047: val_accuracy did not improve from 0.82759
#
# Epoch 00048: val_accuracy did not improve from 0.82759
#
# Epoch 00049: val_accuracy did not improve from 0.82759
#
# Epoch 00050: val_accuracy did not improve from 0.82759
#
# Epoch 00051: val_accuracy did not improve from 0.82759
#
# Epoch 00052: val_accuracy did not improve from 0.82759
#
# Epoch 00053: val_accuracy did not improve from 0.82759
#
# Epoch 00054: val_accuracy did not improve from 0.82759
#
# Epoch 00055: val_accuracy did not improve from 0.82759
#
# Epoch 00056: val_accuracy did not improve from 0.82759
#
# Epoch 00057: val_accuracy did not improve from 0.82759
#
# Epoch 00058: val_accuracy did not improve from 0.82759
#
# Epoch 00059: val_accuracy did not improve from 0.82759
#
# Epoch 00060: val_accuracy did not improve from 0.82759
#
# Epoch 00061: val_accuracy improved from 0.82759 to 0.86207, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_ID_STFTDA09_CV.hdf5
#
# Epoch 00062: val_accuracy did not improve from 0.86207
#
# Epoch 00063: val_accuracy did not improve from 0.86207
#
# Epoch 00064: val_accuracy did not improve from 0.86207
#
# Epoch 00065: val_accuracy did not improve from 0.86207
#
# Epoch 00066: val_accuracy did not improve from 0.86207
#
# Epoch 00067: val_accuracy did not improve from 0.86207
#
# Epoch 00068: val_accuracy did not improve from 0.86207
#
# Epoch 00069: val_accuracy did not improve from 0.86207
#
# Epoch 00070: val_accuracy did not improve from 0.86207
#
# Epoch 00071: val_accuracy did not improve from 0.86207
#
# Epoch 00072: val_accuracy did not improve from 0.86207
#
# Epoch 00073: val_accuracy did not improve from 0.86207
#
# Epoch 00074: val_accuracy did not improve from 0.86207
#
# Epoch 00075: val_accuracy did not improve from 0.86207
#
# Epoch 00076: val_accuracy did not improve from 0.86207
#
# Epoch 00077: val_accuracy did not improve from 0.86207
#
# Epoch 00078: val_accuracy did not improve from 0.86207
#
# Epoch 00079: val_accuracy did not improve from 0.86207
#
# Epoch 00080: val_accuracy did not improve from 0.86207
#
# Epoch 00081: val_accuracy did not improve from 0.86207
#
# Epoch 00082: val_accuracy did not improve from 0.86207
#
# Epoch 00083: val_accuracy did not improve from 0.86207
#
# Epoch 00084: val_accuracy did not improve from 0.86207
#
# Epoch 00085: val_accuracy did not improve from 0.86207
#
# Epoch 00086: val_accuracy did not improve from 0.86207
#
# Epoch 00087: val_accuracy did not improve from 0.86207
#
# Epoch 00088: val_accuracy did not improve from 0.86207
#
# Epoch 00089: val_accuracy did not improve from 0.86207
#
# Epoch 00090: val_accuracy did not improve from 0.86207
#
# Epoch 00091: val_accuracy did not improve from 0.86207
#
# Epoch 00092: val_accuracy did not improve from 0.86207
#
# Epoch 00093: val_accuracy did not improve from 0.86207
#
# Epoch 00094: val_accuracy did not improve from 0.86207
#
# Epoch 00095: val_accuracy did not improve from 0.86207
#
# Epoch 00096: val_accuracy did not improve from 0.86207
#
# Epoch 00097: val_accuracy did not improve from 0.86207
#
# Epoch 00098: val_accuracy did not improve from 0.86207
#
# Epoch 00099: val_accuracy did not improve from 0.86207
#
# Epoch 00100: val_accuracy did not improve from 0.86207
#
# Epoch 00101: val_accuracy did not improve from 0.86207
#
# Epoch 00102: val_accuracy did not improve from 0.86207
#
# Epoch 00103: val_accuracy did not improve from 0.86207
#
# Epoch 00104: val_accuracy did not improve from 0.86207
#
# Epoch 00105: val_accuracy did not improve from 0.86207
#
# Epoch 00106: val_accuracy did not improve from 0.86207
#
# Epoch 00107: val_accuracy did not improve from 0.86207
#
# Epoch 00108: val_accuracy did not improve from 0.86207
#
# Epoch 00109: val_accuracy did not improve from 0.86207
#
# Epoch 00110: val_accuracy did not improve from 0.86207
#
# Epoch 00111: val_accuracy did not improve from 0.86207
#
# Epoch 00112: val_accuracy did not improve from 0.86207
#
# Epoch 00113: val_accuracy did not improve from 0.86207
#
# Epoch 00114: val_accuracy did not improve from 0.86207
#
# Epoch 00115: val_accuracy did not improve from 0.86207
#
# Epoch 00116: val_accuracy improved from 0.86207 to 0.89655, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_ID_STFTDA09_CV.hdf5
#
# Epoch 00117: val_accuracy did not improve from 0.89655
#
# Epoch 00118: val_accuracy did not improve from 0.89655
#
# Epoch 00119: val_accuracy did not improve from 0.89655
#
# Epoch 00120: val_accuracy did not improve from 0.89655
#
# Epoch 00121: val_accuracy did not improve from 0.89655
#
# Epoch 00122: val_accuracy did not improve from 0.89655
#
# Epoch 00123: val_accuracy did not improve from 0.89655
#
# Epoch 00124: val_accuracy did not improve from 0.89655
#
# Epoch 00125: val_accuracy did not improve from 0.89655
#
# Epoch 00126: val_accuracy did not improve from 0.89655
#
# Epoch 00127: val_accuracy did not improve from 0.89655
#
# Epoch 00128: val_accuracy did not improve from 0.89655
#
# Epoch 00129: val_accuracy did not improve from 0.89655
#
# Epoch 00130: val_accuracy did not improve from 0.89655
#
# Epoch 00131: val_accuracy did not improve from 0.89655
#
# Epoch 00132: val_accuracy did not improve from 0.89655
#
# Epoch 00133: val_accuracy did not improve from 0.89655
#
# Epoch 00134: val_accuracy did not improve from 0.89655
#
# Epoch 00135: val_accuracy did not improve from 0.89655
#
# Epoch 00136: val_accuracy did not improve from 0.89655
#
# Epoch 00137: val_accuracy did not improve from 0.89655
#
# Epoch 00138: val_accuracy did not improve from 0.89655
#
# Epoch 00139: val_accuracy did not improve from 0.89655
#
# Epoch 00140: val_accuracy did not improve from 0.89655
#
# Epoch 00141: val_accuracy did not improve from 0.89655
#
# Epoch 00142: val_accuracy did not improve from 0.89655
#
# Epoch 00143: val_accuracy did not improve from 0.89655
#
# Epoch 00144: val_accuracy did not improve from 0.89655
#
# Epoch 00145: val_accuracy did not improve from 0.89655
#
# Epoch 00146: val_accuracy did not improve from 0.89655
#
# Epoch 00147: val_accuracy did not improve from 0.89655
#
# Epoch 00148: val_accuracy did not improve from 0.89655
#
# Epoch 00149: val_accuracy did not improve from 0.89655
#
# Epoch 00150: val_accuracy did not improve from 0.89655
#
# Epoch 00151: val_accuracy did not improve from 0.89655
#
# Epoch 00152: val_accuracy did not improve from 0.89655
#
# Epoch 00153: val_accuracy did not improve from 0.89655
#
# Epoch 00154: val_accuracy did not improve from 0.89655
#
# Epoch 00155: val_accuracy did not improve from 0.89655
#
# Epoch 00156: val_accuracy did not improve from 0.89655
#
# Epoch 00157: val_accuracy did not improve from 0.89655
#
# Epoch 00158: val_accuracy did not improve from 0.89655
#
# Epoch 00159: val_accuracy did not improve from 0.89655
#
# Epoch 00160: val_accuracy did not improve from 0.89655
#
# Epoch 00161: val_accuracy did not improve from 0.89655
#
# Epoch 00162: val_accuracy did not improve from 0.89655
#
# Epoch 00163: val_accuracy did not improve from 0.89655
#
# Epoch 00164: val_accuracy did not improve from 0.89655
#
# Epoch 00165: val_accuracy did not improve from 0.89655
#
# Epoch 00166: val_accuracy did not improve from 0.89655
#
# Epoch 00167: val_accuracy did not improve from 0.89655
#
# Epoch 00168: val_accuracy did not improve from 0.89655
#
# Epoch 00169: val_accuracy did not improve from 0.89655
#
# Epoch 00170: val_accuracy did not improve from 0.89655
#
# Epoch 00171: val_accuracy did not improve from 0.89655
#
# Epoch 00172: val_accuracy did not improve from 0.89655
#
# Epoch 00173: val_accuracy did not improve from 0.89655
#
# Epoch 00174: val_accuracy did not improve from 0.89655
#
# Epoch 00175: val_accuracy did not improve from 0.89655
#
# Epoch 00176: val_accuracy did not improve from 0.89655
#
# Epoch 00177: val_accuracy did not improve from 0.89655
#
# Epoch 00178: val_accuracy did not improve from 0.89655
#
# Epoch 00179: val_accuracy did not improve from 0.89655
#
# Epoch 00180: val_accuracy did not improve from 0.89655
#
# Epoch 00181: val_accuracy did not improve from 0.89655
#
# Epoch 00182: val_accuracy did not improve from 0.89655
#
# Epoch 00183: val_accuracy improved from 0.89655 to 0.93103, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_ID_STFTDA09_CV.hdf5
#
# Epoch 00184: val_accuracy did not improve from 0.93103
#
# Epoch 00185: val_accuracy did not improve from 0.93103
#
# Epoch 00186: val_accuracy did not improve from 0.93103
#
# Epoch 00187: val_accuracy did not improve from 0.93103
#
# Epoch 00188: val_accuracy did not improve from 0.93103
#
# Epoch 00189: val_accuracy did not improve from 0.93103
#
# Epoch 00190: val_accuracy did not improve from 0.93103
#
# Epoch 00191: val_accuracy did not improve from 0.93103
#
# Epoch 00192: val_accuracy did not improve from 0.93103
#
# Epoch 00193: val_accuracy did not improve from 0.93103
#
# Epoch 00194: val_accuracy did not improve from 0.93103
#
# Epoch 00195: val_accuracy did not improve from 0.93103
#
# Epoch 00196: val_accuracy did not improve from 0.93103
#
# Epoch 00197: val_accuracy did not improve from 0.93103
#
# Epoch 00198: val_accuracy did not improve from 0.93103
#
# Epoch 00199: val_accuracy did not improve from 0.93103
#
# Epoch 00200: val_accuracy did not improve from 0.93103
#
# Epoch 00201: val_accuracy did not improve from 0.93103
#
# Epoch 00202: val_accuracy did not improve from 0.93103
#
# Epoch 00203: val_accuracy did not improve from 0.93103
#
# Epoch 00204: val_accuracy did not improve from 0.93103
#
# Epoch 00205: val_accuracy did not improve from 0.93103
#
# Epoch 00206: val_accuracy did not improve from 0.93103
#
# Epoch 00207: val_accuracy did not improve from 0.93103
#
# Epoch 00208: val_accuracy did not improve from 0.93103
#
# Epoch 00209: val_accuracy did not improve from 0.93103
#
# Epoch 00210: val_accuracy did not improve from 0.93103
#
# Epoch 00211: val_accuracy did not improve from 0.93103
#
# Epoch 00212: val_accuracy did not improve from 0.93103
#
# Epoch 00213: val_accuracy did not improve from 0.93103
#
# Epoch 00214: val_accuracy did not improve from 0.93103
#
# Epoch 00215: val_accuracy did not improve from 0.93103
#
# Epoch 00216: val_accuracy did not improve from 0.93103
#
# Epoch 00217: val_accuracy did not improve from 0.93103
#
# Epoch 00218: val_accuracy did not improve from 0.93103
#
# Epoch 00219: val_accuracy did not improve from 0.93103
#
# Epoch 00220: val_accuracy did not improve from 0.93103
#
# Epoch 00221: val_accuracy did not improve from 0.93103
#
# Epoch 00222: val_accuracy did not improve from 0.93103
#
# Epoch 00223: val_accuracy did not improve from 0.93103
#
# Epoch 00224: val_accuracy did not improve from 0.93103
#
# Epoch 00225: val_accuracy did not improve from 0.93103
#
# Epoch 00226: val_accuracy did not improve from 0.93103
#
# Epoch 00227: val_accuracy did not improve from 0.93103
#
# Epoch 00228: val_accuracy did not improve from 0.93103
#
# Epoch 00229: val_accuracy did not improve from 0.93103
#
# Epoch 00230: val_accuracy did not improve from 0.93103
#
# Epoch 00231: val_accuracy did not improve from 0.93103
#
# Epoch 00232: val_accuracy did not improve from 0.93103
#
# Epoch 00233: val_accuracy did not improve from 0.93103
#
# Epoch 00234: val_accuracy did not improve from 0.93103
#
# Epoch 00235: val_accuracy did not improve from 0.93103
#
# Epoch 00236: val_accuracy did not improve from 0.93103
#
# Epoch 00237: val_accuracy did not improve from 0.93103
#
# Epoch 00238: val_accuracy did not improve from 0.93103
#
# Epoch 00239: val_accuracy did not improve from 0.93103
#
# Epoch 00240: val_accuracy did not improve from 0.93103
#
# Epoch 00241: val_accuracy did not improve from 0.93103
#
# Epoch 00242: val_accuracy did not improve from 0.93103
#
# Epoch 00243: val_accuracy did not improve from 0.93103
#
# Epoch 00244: val_accuracy improved from 0.93103 to 0.96552, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_ID_STFTDA09_CV.hdf5
#
# Epoch 00245: val_accuracy did not improve from 0.96552
#
# Epoch 00246: val_accuracy did not improve from 0.96552
#
# Epoch 00247: val_accuracy did not improve from 0.96552
#
# Epoch 00248: val_accuracy did not improve from 0.96552
#
# Epoch 00249: val_accuracy did not improve from 0.96552
#
# Epoch 00250: val_accuracy did not improve from 0.96552
#
# Epoch 00251: val_accuracy did not improve from 0.96552
#
# Epoch 00252: val_accuracy did not improve from 0.96552
#
# Epoch 00253: val_accuracy did not improve from 0.96552
#
# Epoch 00254: val_accuracy did not improve from 0.96552
#
# Epoch 00255: val_accuracy did not improve from 0.96552
#
# Epoch 00256: val_accuracy did not improve from 0.96552
#
# Epoch 00257: val_accuracy did not improve from 0.96552
#
# Epoch 00258: val_accuracy did not improve from 0.96552
#
# Epoch 00259: val_accuracy did not improve from 0.96552
#
# Epoch 00260: val_accuracy did not improve from 0.96552
#
# Epoch 00261: val_accuracy did not improve from 0.96552
#
# Epoch 00262: val_accuracy did not improve from 0.96552
#
# Epoch 00263: val_accuracy did not improve from 0.96552
#
# Epoch 00264: val_accuracy did not improve from 0.96552
#
# Epoch 00265: val_accuracy did not improve from 0.96552
#
# Epoch 00266: val_accuracy did not improve from 0.96552
#
# Epoch 00267: val_accuracy did not improve from 0.96552
#
# Epoch 00268: val_accuracy did not improve from 0.96552
#
# Epoch 00269: val_accuracy did not improve from 0.96552
#
# Epoch 00270: val_accuracy did not improve from 0.96552
#
# Epoch 00271: val_accuracy did not improve from 0.96552
#
# Epoch 00272: val_accuracy did not improve from 0.96552
#
# Epoch 00273: val_accuracy did not improve from 0.96552
#
# Epoch 00274: val_accuracy did not improve from 0.96552
#
# Epoch 00275: val_accuracy did not improve from 0.96552
#
# Epoch 00276: val_accuracy did not improve from 0.96552
#
# Epoch 00277: val_accuracy did not improve from 0.96552
#
# Epoch 00278: val_accuracy did not improve from 0.96552
#
# Epoch 00279: val_accuracy did not improve from 0.96552
#
# Epoch 00280: val_accuracy did not improve from 0.96552
#
# Epoch 00281: val_accuracy did not improve from 0.96552
#
# Epoch 00282: val_accuracy did not improve from 0.96552
#
# Epoch 00283: val_accuracy did not improve from 0.96552
#
# Epoch 00284: val_accuracy did not improve from 0.96552
#
# Epoch 00285: val_accuracy did not improve from 0.96552
#
# Epoch 00286: val_accuracy did not improve from 0.96552
#
# Epoch 00287: val_accuracy did not improve from 0.96552
#
# Epoch 00288: val_accuracy did not improve from 0.96552
#
# Epoch 00289: val_accuracy did not improve from 0.96552
#
# Epoch 00290: val_accuracy did not improve from 0.96552
#
# Epoch 00291: val_accuracy did not improve from 0.96552
#
# Epoch 00292: val_accuracy did not improve from 0.96552
#
# Epoch 00293: val_accuracy did not improve from 0.96552
#
# Epoch 00294: val_accuracy did not improve from 0.96552
#
# Epoch 00295: val_accuracy did not improve from 0.96552
#
# Epoch 00296: val_accuracy did not improve from 0.96552
#
# Epoch 00297: val_accuracy did not improve from 0.96552
#
# Epoch 00298: val_accuracy did not improve from 0.96552
#
# Epoch 00299: val_accuracy did not improve from 0.96552
#
# Epoch 00300: val_accuracy did not improve from 0.96552
#
# Epoch 00301: val_accuracy did not improve from 0.96552
#
# Epoch 00302: val_accuracy did not improve from 0.96552
#
# Epoch 00303: val_accuracy did not improve from 0.96552
#
# Epoch 00304: val_accuracy did not improve from 0.96552
#
# Epoch 00305: val_accuracy did not improve from 0.96552
#
# Epoch 00306: val_accuracy did not improve from 0.96552
#
# Epoch 00307: val_accuracy did not improve from 0.96552
#
# Epoch 00308: val_accuracy did not improve from 0.96552
#
# Epoch 00309: val_accuracy did not improve from 0.96552
#
# Epoch 00310: val_accuracy did not improve from 0.96552
#
# Epoch 00311: val_accuracy did not improve from 0.96552
#
# Epoch 00312: val_accuracy did not improve from 0.96552
#
# Epoch 00313: val_accuracy did not improve from 0.96552
#
# Epoch 00314: val_accuracy did not improve from 0.96552
#
# Epoch 00315: val_accuracy did not improve from 0.96552
#
# Epoch 00316: val_accuracy did not improve from 0.96552
#
# Epoch 00317: val_accuracy did not improve from 0.96552
#
# Epoch 00318: val_accuracy did not improve from 0.96552
#
# Epoch 00319: val_accuracy did not improve from 0.96552
#
# Epoch 00320: val_accuracy did not improve from 0.96552
#
# Epoch 00321: val_accuracy did not improve from 0.96552
#
# Epoch 00322: val_accuracy did not improve from 0.96552
#
# Epoch 00323: val_accuracy did not improve from 0.96552
#
# Epoch 00324: val_accuracy did not improve from 0.96552
#
# Epoch 00325: val_accuracy did not improve from 0.96552
#
# Epoch 00326: val_accuracy did not improve from 0.96552
#
# Epoch 00327: val_accuracy did not improve from 0.96552
#
# Epoch 00328: val_accuracy did not improve from 0.96552
#
# Epoch 00329: val_accuracy did not improve from 0.96552
#
# Epoch 00330: val_accuracy did not improve from 0.96552
#
# Epoch 00331: val_accuracy did not improve from 0.96552
#
# Epoch 00332: val_accuracy did not improve from 0.96552
#
# Epoch 00333: val_accuracy did not improve from 0.96552
#
# Epoch 00334: val_accuracy did not improve from 0.96552
#
# Epoch 00335: val_accuracy did not improve from 0.96552
#
# Epoch 00336: val_accuracy did not improve from 0.96552
#
# Epoch 00337: val_accuracy did not improve from 0.96552
#
# Epoch 00338: val_accuracy did not improve from 0.96552
#
# Epoch 00339: val_accuracy did not improve from 0.96552
#
# Epoch 00340: val_accuracy did not improve from 0.96552
#
# Epoch 00341: val_accuracy did not improve from 0.96552
#
# Epoch 00342: val_accuracy did not improve from 0.96552
#
# Epoch 00343: val_accuracy did not improve from 0.96552
#
# Epoch 00344: val_accuracy did not improve from 0.96552
#
# Epoch 00345: val_accuracy did not improve from 0.96552
#
# Epoch 00346: val_accuracy did not improve from 0.96552
#
# Epoch 00347: val_accuracy did not improve from 0.96552
#
# Epoch 00348: val_accuracy did not improve from 0.96552
#
# Epoch 00349: val_accuracy did not improve from 0.96552
#
# Epoch 00350: val_accuracy did not improve from 0.96552
#
# Epoch 00351: val_accuracy did not improve from 0.96552
#
# Epoch 00352: val_accuracy did not improve from 0.96552
#
# Epoch 00353: val_accuracy did not improve from 0.96552
#
# Epoch 00354: val_accuracy did not improve from 0.96552
#
# Epoch 00355: val_accuracy did not improve from 0.96552
#
# Epoch 00356: val_accuracy did not improve from 0.96552
#
# Epoch 00357: val_accuracy did not improve from 0.96552
#
# Epoch 00358: val_accuracy did not improve from 0.96552
#
# Epoch 00359: val_accuracy did not improve from 0.96552
#
# Epoch 00360: val_accuracy did not improve from 0.96552
#
# Epoch 00361: val_accuracy did not improve from 0.96552
#
# Epoch 00362: val_accuracy did not improve from 0.96552
#
# Epoch 00363: val_accuracy did not improve from 0.96552
#
# Epoch 00364: val_accuracy did not improve from 0.96552
#
# Epoch 00365: val_accuracy did not improve from 0.96552
#
# Epoch 00366: val_accuracy did not improve from 0.96552
#
# Epoch 00367: val_accuracy did not improve from 0.96552
#
# Epoch 00368: val_accuracy did not improve from 0.96552
#
# Epoch 00369: val_accuracy did not improve from 0.96552
#
# Epoch 00370: val_accuracy did not improve from 0.96552
#
# Epoch 00371: val_accuracy did not improve from 0.96552
#
# Epoch 00372: val_accuracy did not improve from 0.96552
#
# Epoch 00373: val_accuracy did not improve from 0.96552
#
# Epoch 00374: val_accuracy did not improve from 0.96552
#
# Epoch 00375: val_accuracy did not improve from 0.96552
#
# Epoch 00376: val_accuracy did not improve from 0.96552
#
# Epoch 00377: val_accuracy did not improve from 0.96552
#
# Epoch 00378: val_accuracy did not improve from 0.96552
#
# Epoch 00379: val_accuracy did not improve from 0.96552
#
# Epoch 00380: val_accuracy did not improve from 0.96552
#
# Epoch 00381: val_accuracy did not improve from 0.96552
#
# Epoch 00382: val_accuracy did not improve from 0.96552
#
# Epoch 00383: val_accuracy did not improve from 0.96552
#
# Epoch 00384: val_accuracy did not improve from 0.96552
#
# Epoch 00385: val_accuracy did not improve from 0.96552
#
# Epoch 00386: val_accuracy did not improve from 0.96552
#
# Epoch 00387: val_accuracy did not improve from 0.96552
#
# Epoch 00388: val_accuracy did not improve from 0.96552
#
# Epoch 00389: val_accuracy did not improve from 0.96552
#
# Epoch 00390: val_accuracy did not improve from 0.96552
#
# Epoch 00391: val_accuracy did not improve from 0.96552
#
# Epoch 00392: val_accuracy did not improve from 0.96552
#
# Epoch 00393: val_accuracy did not improve from 0.96552
#
# Epoch 00394: val_accuracy did not improve from 0.96552
#
# Epoch 00395: val_accuracy did not improve from 0.96552
#
# Epoch 00396: val_accuracy did not improve from 0.96552
#
# Epoch 00397: val_accuracy did not improve from 0.96552
#
# Epoch 00398: val_accuracy did not improve from 0.96552
#
# Epoch 00399: val_accuracy did not improve from 0.96552
#
# Epoch 00400: val_accuracy did not improve from 0.96552
# loss:  0.30164337158203125
# accuracy:  0.8620689511299133
# kappa:  0.7264150943396226
# confusion matrix:
#  [[14  0]
#  [ 4 11]]
# AUC 0.9666666666666667
# Iteration: 3
#
# Epoch 00001: val_accuracy did not improve from 0.96552
#
# Epoch 00002: val_accuracy did not improve from 0.96552
#
# Epoch 00003: val_accuracy did not improve from 0.96552
#
# Epoch 00004: val_accuracy did not improve from 0.96552
#
# Epoch 00005: val_accuracy did not improve from 0.96552
#
# Epoch 00006: val_accuracy did not improve from 0.96552
#
# Epoch 00007: val_accuracy did not improve from 0.96552
#
# Epoch 00008: val_accuracy did not improve from 0.96552
#
# Epoch 00009: val_accuracy did not improve from 0.96552
#
# Epoch 00010: val_accuracy did not improve from 0.96552
#
# Epoch 00011: val_accuracy did not improve from 0.96552
#
# Epoch 00012: val_accuracy did not improve from 0.96552
#
# Epoch 00013: val_accuracy did not improve from 0.96552
#
# Epoch 00014: val_accuracy did not improve from 0.96552
#
# Epoch 00015: val_accuracy did not improve from 0.96552
#
# Epoch 00016: val_accuracy did not improve from 0.96552
#
# Epoch 00017: val_accuracy did not improve from 0.96552
#
# Epoch 00018: val_accuracy did not improve from 0.96552
#
# Epoch 00019: val_accuracy did not improve from 0.96552
#
# Epoch 00020: val_accuracy did not improve from 0.96552
#
# Epoch 00021: val_accuracy did not improve from 0.96552
#
# Epoch 00022: val_accuracy did not improve from 0.96552
#
# Epoch 00023: val_accuracy did not improve from 0.96552
#
# Epoch 00024: val_accuracy did not improve from 0.96552
#
# Epoch 00025: val_accuracy did not improve from 0.96552
#
# Epoch 00026: val_accuracy did not improve from 0.96552
#
# Epoch 00027: val_accuracy did not improve from 0.96552
#
# Epoch 00028: val_accuracy did not improve from 0.96552
#
# Epoch 00029: val_accuracy did not improve from 0.96552
#
# Epoch 00030: val_accuracy did not improve from 0.96552
#
# Epoch 00031: val_accuracy did not improve from 0.96552
#
# Epoch 00032: val_accuracy did not improve from 0.96552
#
# ...
#
# Epoch 00134: val_accuracy did not improve from 1.00000
#
# Epoch 00135: val_accuracy did not improve from 1.00000
#
# Epoch 00136: val_accuracy did not improve from 1.00000
#
# Epoch 00137: val_accuracy did not improve from 1.00000
#
# Epoch 00138: val_accuracy did not improve from 1.00000
#
# Epoch 00139: val_accuracy did not improve from 1.00000
#
# Epoch 00140: val_accuracy did not improve from 1.00000
#
# Epoch 00141: val_accuracy did not improve from 1.00000
#
# Epoch 00142: val_accuracy did not improve from 1.00000
#
# Epoch 00143: val_accuracy did not improve from 1.00000
#
# Epoch 00144: val_accuracy did not improve from 1.00000
#
# Epoch 00145: val_accuracy did not improve from 1.00000
#
# Epoch 00146: val_accuracy did not improve from 1.00000
#
# Epoch 00147: val_accuracy did not improve from 1.00000
#
# Epoch 00148: val_accuracy did not improve from 1.00000
#
# Epoch 00149: val_accuracy did not improve from 1.00000
#
# Epoch 00150: val_accuracy did not improve from 1.00000
#
# Epoch 00151: val_accuracy did not improve from 1.00000
#
# Epoch 00152: val_accuracy did not improve from 1.00000
#
# Epoch 00153: val_accuracy did not improve from 1.00000
#
# Epoch 00154: val_accuracy did not improve from 1.00000
#
# Epoch 00155: val_accuracy did not improve from 1.00000
#
# Epoch 00156: val_accuracy did not improve from 1.00000
#
# Epoch 00157: val_accuracy did not improve from 1.00000
#
# Epoch 00158: val_accuracy did not improve from 1.00000
#
# Epoch 00159: val_accuracy did not improve from 1.00000
#
# Epoch 00160: val_accuracy did not improve from 1.00000
#
# Epoch 00161: val_accuracy did not improve from 1.00000
#
# Epoch 00162: val_accuracy did not improve from 1.00000
#
# Epoch 00163: val_accuracy did not improve from 1.00000
#
# Epoch 00164: val_accuracy did not improve from 1.00000
#
# Epoch 00165: val_accuracy did not improve from 1.00000
#
# Epoch 00166: val_accuracy did not improve from 1.00000
#
# Epoch 00167: val_accuracy did not improve from 1.00000
#
# Epoch 00168: val_accuracy did not improve from 1.00000
#
# Epoch 00169: val_accuracy did not improve from 1.00000
#
# Epoch 00170: val_accuracy did not improve from 1.00000
#
# Epoch 00171: val_accuracy did not improve from 1.00000
#
# Epoch 00172: val_accuracy did not improve from 1.00000
#
# Epoch 00173: val_accuracy did not improve from 1.00000
#
# Epoch 00174: val_accuracy did not improve from 1.00000
#
# Epoch 00175: val_accuracy did not improve from 1.00000
#
# Epoch 00176: val_accuracy did not improve from 1.00000
#
# Epoch 00177: val_accuracy did not improve from 1.00000
#
# Epoch 00178: val_accuracy did not improve from 1.00000
#
# Epoch 00179: val_accuracy did not improve from 1.00000
#
# Epoch 00180: val_accuracy did not improve from 1.00000
#
# Epoch 00181: val_accuracy did not improve from 1.00000
#
# Epoch 00182: val_accuracy did not improve from 1.00000
#
# Epoch 00183: val_accuracy did not improve from 1.00000
#
# Epoch 00184: val_accuracy did not improve from 1.00000
#
# Epoch 00185: val_accuracy did not improve from 1.00000
#
# Epoch 00186: val_accuracy did not improve from 1.00000
#
# Epoch 00187: val_accuracy did not improve from 1.00000
#
# Epoch 00188: val_accuracy did not improve from 1.00000
#
# Epoch 00189: val_accuracy did not improve from 1.00000
#
# Epoch 00190: val_accuracy did not improve from 1.00000
#
# Epoch 00191: val_accuracy did not improve from 1.00000
#
# Epoch 00192: val_accuracy did not improve from 1.00000
#
# Epoch 00193: val_accuracy did not improve from 1.00000
#
# Epoch 00194: val_accuracy did not improve from 1.00000
#
# Epoch 00195: val_accuracy did not improve from 1.00000
#
# Epoch 00196: val_accuracy did not improve from 1.00000
#
# Epoch 00197: val_accuracy did not improve from 1.00000
#
# Epoch 00198: val_accuracy did not improve from 1.00000
#
# Epoch 00199: val_accuracy did not improve from 1.00000
#
# Epoch 00200: val_accuracy did not improve from 1.00000
#
# Epoch 00201: val_accuracy did not improve from 1.00000
#
# Epoch 00202: val_accuracy did not improve from 1.00000
#
# Epoch 00203: val_accuracy did not improve from 1.00000
#
# Epoch 00204: val_accuracy did not improve from 1.00000
#
# Epoch 00205: val_accuracy did not improve from 1.00000
#
# Epoch 00206: val_accuracy did not improve from 1.00000
#
# Epoch 00207: val_accuracy did not improve from 1.00000
#
# Epoch 00208: val_accuracy did not improve from 1.00000
#
# Epoch 00209: val_accuracy did not improve from 1.00000
#
# Epoch 00210: val_accuracy did not improve from 1.00000
#
# Epoch 00211: val_accuracy did not improve from 1.00000
#
# Epoch 00212: val_accuracy did not improve from 1.00000
#
# Epoch 00213: val_accuracy did not improve from 1.00000
#
# Epoch 00214: val_accuracy did not improve from 1.00000
#
# Epoch 00215: val_accuracy did not improve from 1.00000
#
# Epoch 00216: val_accuracy did not improve from 1.00000
#
# Epoch 00217: val_accuracy did not improve from 1.00000
#
# Epoch 00218: val_accuracy did not improve from 1.00000
#
# Epoch 00219: val_accuracy did not improve from 1.00000
#
# Epoch 00220: val_accuracy did not improve from 1.00000
#
# Epoch 00221: val_accuracy did not improve from 1.00000
#
# Epoch 00222: val_accuracy did not improve from 1.00000
#
# Epoch 00223: val_accuracy did not improve from 1.00000
#
# Epoch 00224: val_accuracy did not improve from 1.00000
#
# Epoch 00225: val_accuracy did not improve from 1.00000
#
# Epoch 00226: val_accuracy did not improve from 1.00000
#
# Epoch 00227: val_accuracy did not improve from 1.00000
#
# Epoch 00228: val_accuracy did not improve from 1.00000
#
# Epoch 00229: val_accuracy did not improve from 1.00000
#
# Epoch 00230: val_accuracy did not improve from 1.00000
#
# Epoch 00231: val_accuracy did not improve from 1.00000
#
# Epoch 00232: val_accuracy did not improve from 1.00000
#
# Epoch 00233: val_accuracy did not improve from 1.00000
#
# Epoch 00234: val_accuracy did not improve from 1.00000
#
# Epoch 00235: val_accuracy did not improve from 1.00000
#
# Epoch 00236: val_accuracy did not improve from 1.00000
#
# Epoch 00237: val_accuracy did not improve from 1.00000
#
# Epoch 00238: val_accuracy did not improve from 1.00000
#
# Epoch 00239: val_accuracy did not improve from 1.00000
#
# Epoch 00240: val_accuracy did not improve from 1.00000
#
# Epoch 00241: val_accuracy did not improve from 1.00000
#
# Epoch 00242: val_accuracy did not improve from 1.00000
#
# Epoch 00243: val_accuracy did not improve from 1.00000
#
# Epoch 00244: val_accuracy did not improve from 1.00000
#
# Epoch 00245: val_accuracy did not improve from 1.00000
#
# Epoch 00246: val_accuracy did not improve from 1.00000
#
# Epoch 00247: val_accuracy did not improve from 1.00000
#
# Epoch 00248: val_accuracy did not improve from 1.00000
#
# Epoch 00249: val_accuracy did not improve from 1.00000
#
# Epoch 00250: val_accuracy did not improve from 1.00000
#
# Epoch 00251: val_accuracy did not improve from 1.00000
#
# Epoch 00252: val_accuracy did not improve from 1.00000
#
# Epoch 00253: val_accuracy did not improve from 1.00000
#
# Epoch 00254: val_accuracy did not improve from 1.00000
#
# Epoch 00255: val_accuracy did not improve from 1.00000
#
# Epoch 00256: val_accuracy did not improve from 1.00000
#
# Epoch 00257: val_accuracy did not improve from 1.00000
#
# Epoch 00258: val_accuracy did not improve from 1.00000
#
# Epoch 00259: val_accuracy did not improve from 1.00000
#
# Epoch 00260: val_accuracy did not improve from 1.00000
#
# Epoch 00261: val_accuracy did not improve from 1.00000
#
# Epoch 00262: val_accuracy did not improve from 1.00000
#
# Epoch 00263: val_accuracy did not improve from 1.00000
#
# Epoch 00264: val_accuracy did not improve from 1.00000
#
# Epoch 00265: val_accuracy did not improve from 1.00000
#
# Epoch 00266: val_accuracy did not improve from 1.00000
#
# Epoch 00267: val_accuracy did not improve from 1.00000
#
# Epoch 00268: val_accuracy did not improve from 1.00000
#
# Epoch 00269: val_accuracy did not improve from 1.00000
#
# Epoch 00270: val_accuracy did not improve from 1.00000
#
# Epoch 00271: val_accuracy did not improve from 1.00000
#
# Epoch 00272: val_accuracy did not improve from 1.00000
#
# Epoch 00273: val_accuracy did not improve from 1.00000
#
# Epoch 00274: val_accuracy did not improve from 1.00000
#
# Epoch 00275: val_accuracy did not improve from 1.00000
#
# Epoch 00276: val_accuracy did not improve from 1.00000
#
# Epoch 00277: val_accuracy did not improve from 1.00000
#
# Epoch 00278: val_accuracy did not improve from 1.00000
#
# Epoch 00279: val_accuracy did not improve from 1.00000
#
# Epoch 00280: val_accuracy did not improve from 1.00000
#
# Epoch 00281: val_accuracy did not improve from 1.00000
#
# Epoch 00282: val_accuracy did not improve from 1.00000
#
# Epoch 00283: val_accuracy did not improve from 1.00000
#
# Epoch 00284: val_accuracy did not improve from 1.00000
#
# Epoch 00285: val_accuracy did not improve from 1.00000
#
# Epoch 00286: val_accuracy did not improve from 1.00000
#
# Epoch 00287: val_accuracy did not improve from 1.00000
#
# Epoch 00288: val_accuracy did not improve from 1.00000
#
# Epoch 00289: val_accuracy did not improve from 1.00000
#
# Epoch 00290: val_accuracy did not improve from 1.00000
#
# Epoch 00291: val_accuracy did not improve from 1.00000
#
# Epoch 00292: val_accuracy did not improve from 1.00000
#
# Epoch 00293: val_accuracy did not improve from 1.00000
#
# Epoch 00294: val_accuracy did not improve from 1.00000
#
# Epoch 00295: val_accuracy did not improve from 1.00000
#
# Epoch 00296: val_accuracy did not improve from 1.00000
#
# Epoch 00297: val_accuracy did not improve from 1.00000
#
# Epoch 00298: val_accuracy did not improve from 1.00000
#
# Epoch 00299: val_accuracy did not improve from 1.00000
#
# Epoch 00300: val_accuracy did not improve from 1.00000
#
# Epoch 00301: val_accuracy did not improve from 1.00000
#
# Epoch 00302: val_accuracy did not improve from 1.00000
#
# Epoch 00303: val_accuracy did not improve from 1.00000
#
# Epoch 00304: val_accuracy did not improve from 1.00000
#
# Epoch 00305: val_accuracy did not improve from 1.00000
#
# Epoch 00306: val_accuracy did not improve from 1.00000
#
# Epoch 00307: val_accuracy did not improve from 1.00000
#
# Epoch 00308: val_accuracy did not improve from 1.00000
#
# Epoch 00309: val_accuracy did not improve from 1.00000
#
# Epoch 00310: val_accuracy did not improve from 1.00000
#
# Epoch 00311: val_accuracy did not improve from 1.00000
#
# Epoch 00312: val_accuracy did not improve from 1.00000
#
# Epoch 00313: val_accuracy did not improve from 1.00000
#
# Epoch 00314: val_accuracy did not improve from 1.00000
#
# Epoch 00315: val_accuracy did not improve from 1.00000
#
# Epoch 00316: val_accuracy did not improve from 1.00000
#
# Epoch 00317: val_accuracy did not improve from 1.00000
#
# Epoch 00318: val_accuracy did not improve from 1.00000
#
# Epoch 00319: val_accuracy did not improve from 1.00000
#
# Epoch 00320: val_accuracy did not improve from 1.00000
#
# Epoch 00321: val_accuracy did not improve from 1.00000
#
# Epoch 00322: val_accuracy did not improve from 1.00000
#
# Epoch 00323: val_accuracy did not improve from 1.00000
#
# Epoch 00324: val_accuracy did not improve from 1.00000
#
# Epoch 00325: val_accuracy did not improve from 1.00000
#
# Epoch 00326: val_accuracy did not improve from 1.00000
#
# Epoch 00327: val_accuracy did not improve from 1.00000
#
# Epoch 00328: val_accuracy did not improve from 1.00000
#
# Epoch 00329: val_accuracy did not improve from 1.00000
#
# Epoch 00330: val_accuracy did not improve from 1.00000
#
# Epoch 00331: val_accuracy did not improve from 1.00000
#
# Epoch 00332: val_accuracy did not improve from 1.00000
#
# Epoch 00333: val_accuracy did not improve from 1.00000
#
# Epoch 00334: val_accuracy did not improve from 1.00000
#
# Epoch 00335: val_accuracy did not improve from 1.00000
#
# Epoch 00336: val_accuracy did not improve from 1.00000
#
# Epoch 00337: val_accuracy did not improve from 1.00000
#
# Epoch 00338: val_accuracy did not improve from 1.00000
#
# Epoch 00339: val_accuracy did not improve from 1.00000
#
# Epoch 00340: val_accuracy did not improve from 1.00000
#
# Epoch 00341: val_accuracy did not improve from 1.00000
#
# Epoch 00342: val_accuracy did not improve from 1.00000
#
# Epoch 00343: val_accuracy did not improve from 1.00000
#
# Epoch 00344: val_accuracy did not improve from 1.00000
#
# Epoch 00345: val_accuracy did not improve from 1.00000
#
# Epoch 00346: val_accuracy did not improve from 1.00000
#
# Epoch 00347: val_accuracy did not improve from 1.00000
#
# Epoch 00348: val_accuracy did not improve from 1.00000
#
# Epoch 00349: val_accuracy did not improve from 1.00000
#
# Epoch 00350: val_accuracy did not improve from 1.00000
#
# Epoch 00351: val_accuracy did not improve from 1.00000
#
# Epoch 00352: val_accuracy did not improve from 1.00000
#
# Epoch 00353: val_accuracy did not improve from 1.00000
#
# Epoch 00354: val_accuracy did not improve from 1.00000
#
# Epoch 00355: val_accuracy did not improve from 1.00000
#
# Epoch 00356: val_accuracy did not improve from 1.00000
#
# Epoch 00357: val_accuracy did not improve from 1.00000
#
# Epoch 00358: val_accuracy did not improve from 1.00000
#
# Epoch 00359: val_accuracy did not improve from 1.00000
#
# Epoch 00360: val_accuracy did not improve from 1.00000
#
# Epoch 00361: val_accuracy did not improve from 1.00000
#
# Epoch 00362: val_accuracy did not improve from 1.00000
#
# Epoch 00363: val_accuracy did not improve from 1.00000
#
# Epoch 00364: val_accuracy did not improve from 1.00000
#
# Epoch 00365: val_accuracy did not improve from 1.00000
#
# Epoch 00366: val_accuracy did not improve from 1.00000
#
# Epoch 00367: val_accuracy did not improve from 1.00000
#
# Epoch 00368: val_accuracy did not improve from 1.00000
#
# Epoch 00369: val_accuracy did not improve from 1.00000
#
# Epoch 00370: val_accuracy did not improve from 1.00000
#
# Epoch 00371: val_accuracy did not improve from 1.00000
#
# Epoch 00372: val_accuracy did not improve from 1.00000
#
# Epoch 00373: val_accuracy did not improve from 1.00000
#
# Epoch 00374: val_accuracy did not improve from 1.00000
#
# Epoch 00375: val_accuracy did not improve from 1.00000
#
# Epoch 00376: val_accuracy did not improve from 1.00000
#
# Epoch 00377: val_accuracy did not improve from 1.00000
#
# Epoch 00378: val_accuracy did not improve from 1.00000
#
# Epoch 00379: val_accuracy did not improve from 1.00000
#
# Epoch 00380: val_accuracy did not improve from 1.00000
#
# Epoch 00381: val_accuracy did not improve from 1.00000
#
# Epoch 00382: val_accuracy did not improve from 1.00000
#
# Epoch 00383: val_accuracy did not improve from 1.00000
#
# Epoch 00384: val_accuracy did not improve from 1.00000
#
# Epoch 00385: val_accuracy did not improve from 1.00000
#
# Epoch 00386: val_accuracy did not improve from 1.00000
#
# Epoch 00387: val_accuracy did not improve from 1.00000
#
# Epoch 00388: val_accuracy did not improve from 1.00000
#
# Epoch 00389: val_accuracy did not improve from 1.00000
#
# Epoch 00390: val_accuracy did not improve from 1.00000
#
# Epoch 00391: val_accuracy did not improve from 1.00000
#
# Epoch 00392: val_accuracy did not improve from 1.00000
#
# Epoch 00393: val_accuracy did not improve from 1.00000
#
# Epoch 00394: val_accuracy did not improve from 1.00000
#
# Epoch 00395: val_accuracy did not improve from 1.00000
#
# Epoch 00396: val_accuracy did not improve from 1.00000
#
# Epoch 00397: val_accuracy did not improve from 1.00000
#
# Epoch 00398: val_accuracy did not improve from 1.00000
#
# Epoch 00399: val_accuracy did not improve from 1.00000
#
# Epoch 00400: val_accuracy did not improve from 1.00000
# loss:  0.37142202258110046
# accuracy:  0.8214285969734192
# kappa:  0.6428571428571428
# confusion matrix:
#  [[ 9  5]
#  [ 0 14]]
# AUC 0.9846938775510204
# Resultados:
# loss: [0.6956948041915894, 0.30164337158203125, 0.23146691918373108, 0.1787554770708084, 0.33015206456184387, 0.1485927253961563, 0.11473170667886734, 0.4647215008735657, 0.13762249052524567, 0.37142202258110046]
# accuracy: [0.7241379022598267, 0.8620689511299133, 0.8620689511299133, 0.931034505367279, 0.8965517282485962, 0.9655172228813171, 0.9655172228813171, 0.7931034564971924, 0.9285714030265808, 0.8214285969734192]
# kappa: [0.4528301886792453, 0.7264150943396226, 0.7238095238095238, 0.861904761904762, 0.7923627684964201, 0.9307875894988067, 0.9311163895486936, 0.5817307692307692, 0.8571428571428572, 0.6428571428571428]
# AUC: [0.7714285714285715, 0.9666666666666667, 0.9619047619047618, 0.980952380952381, 0.9476190476190476, 0.9761904761904763, 1.0, 0.8857142857142857, 0.9948979591836735, 0.9846938775510204]
# Tiempo: 595.0298347473145

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 264, 8, 16)        160
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 132, 4, 16)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 132, 4, 16)        2320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 66, 2, 16)         0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 2112)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               270464
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 273,202
# Trainable params: 273,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
print("Mean Accuracy: %.4f" % np.mean(array_acc))
print("std: (+/- %.4f)" % np.std(array_acc))
print("Mean Kappa: %.4f" % np.mean(array_kappa))
print("std: (+/- %.4f)" % np.std(array_kappa))
print("Mean AUC: %.4f" % np.mean(array_auc))
print("std: (+/- %.4f)" % np.std(array_auc))
print("Max Accuracy: %.4f" % np.max(array_acc))
print("Max Kappa: %.4f" % np.max(array_kappa))
print("Max AUC: %.4f" % np.max(array_auc))
# Out:
# Mean Accuracy: 0.8750
# std: (+/- 0.0745)
# Mean Kappa: 0.7501
# std: (+/- 0.1485)
# Mean AUC: 0.9470
# std: (+/- 0.0661)
# Max Accuracy: 0.9655
# Max Kappa: 0.9311
# Max AUC: 1.0000

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sun May 24 22:19:35 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    32W / 250W |   1139MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
