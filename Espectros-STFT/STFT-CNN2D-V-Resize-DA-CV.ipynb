# %% [markdown]
# ### Edgar Moises Hernandez-Gonzalez
# #### 13/05/20-15/05/20
# #### Clasificacion de imagenes motoras en EEG con CNN-2D
# ##### Caracteristicas = Espectrogramas STFFT (3D)
# ##### Concatenacion vertical
# ##### Resize proporcional de 264x8
# ##### Data Augmentation
# ##### Validacion cruzada

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import cohen_kappa_score, confusion_matrix
from scipy.signal import spectrogram
import cv2
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras import backend as K

# %%
# para que este script funcione debe de decir 'channels_last', si dice 'channels_first' no sirve
K.image_data_format()
# Out:
# 'channels_last'

# %%
x_train = pd.read_csv("/content/drive/My Drive/BCI-IV-2a/RAW/MI-EEG-A09T.csv", header=None)
x_test = pd.read_csv("/content/drive/My Drive/BCI-IV-2a/RAW/MI-EEG-A09E.csv", header=None)
y_train = pd.read_csv("/content/drive/My Drive/BCI-IV-2a/RAW/EtiquetasA09T.csv", header=None)
y_test = pd.read_csv("/content/drive/My Drive/BCI-IV-2a/RAW/EtiquetasA09E.csv", header=None)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (288, 22000)
# (288, 22000)
# (288, 1)
# (288, 1)

# %%
x = pd.concat([x_train, x_test])
y = pd.concat([y_train, y_test])

# %%
print(x.shape)
print(y.shape)
# Out:
# (576, 22000)
# (576, 1)

# %%
# en caso de no tener el y_test se puede utilizar el x_test
n_samples = len(y)

print("n_samples:", n_samples)
# Out:
# n_samples: 576

# %%
# esto se podria calcular asi n_clases = len(np.unique(y)), la y puede ser train o test
n_classes = len(np.unique(y))

print("n_classes:", n_classes)
# Out:
# n_classes: 4

# %%
# codificar etiquetas con valores de 0 a nClases-1
y = LabelEncoder().fit_transform(y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# las etiquetas en categorical para poder entrenar data augmentation
y_categorical = to_categorical(y)

# %%
#unir 22 canales y resize de tamaño proporcional
def unir_espectrogramas_vertical_resize(data):
  dim = (8, 264) #ancho, alto
  fs = 250
  datos = np.zeros((576,264,8))
  temporal = np.zeros((528,4))
  for i in range(data.shape[0]): #288 muestras
    for j in range(22): #22 canales
      sig = data.iloc[i, j*1000:(j+1)*1000]
      f, t, Sxx = spectrogram(sig, fs) #espectrograma de STFFT
      temporal[j*24:(j+1)*24, :] = Sxx[8:32, :]
    resized = cv2.resize(temporal, dim, interpolation=cv2.INTER_AREA)
    datos[i] = resized
    if i % 100 == 0: #esto solo es para ver como avanza
      print(i)
  return datos

# %%
#llamar a unir_espectrogramas_vertical_resize(data)
x = unir_espectrogramas_vertical_resize(x)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500

# %%
print(x.shape)
# Out:
# (576, 264, 8)

# %%
print(np.max(x))
print(np.min(x))
print(np.mean(x))
# Out:
# 555.4778442263605
# 0.0007544479629820306
# 4.019159298145114

# %%
#convertir a float
x = x.astype('float32')

#escalar los valores en un rango de 0 a 1 (normalizar)
x /= np.ceil(np.max(x))

# %%
print(np.max(x))
print(np.min(x))
print(np.mean(x))
# Out:
# 0.99906087
# 1.3569207e-06
# 0.0072287037

# %%
#convertir de 3D a 4D
x = x.reshape((x.shape[0], x.shape[1], x.shape[2], 1))

print(x.shape)
# Out:
# (576, 264, 8, 1)

# %%
datagen = ImageDataGenerator(width_shift_range=0.25)

# %%
mc = ModelCheckpoint('/content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5',
                     monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
skf = StratifiedKFold(n_splits = 10)

# %%
def CNN_2D():
  model = Sequential()
  model.add(Conv2D(16, (3,3), activation='relu', padding='same',
                   input_shape=x_train.shape[1:]))
  model.add(MaxPool2D((2,2)))
  model.add(Conv2D(16, (3,3), activation='relu', padding='same'))
  model.add(MaxPool2D((2,2)))
  model.add(Flatten())
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(n_classes, activation='softmax'))

  optimizer = Adam(lr=1e-4)
  model.compile(optimizer = optimizer,
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])
  return model

# %%
inicio = time.time()
array_loss = []
array_acc = []
array_kappa = []
i = 0
for iTrain, jTest in skf.split(x, y):
  print("\nIteration:", i + 1)
  x_train, x_test = x[iTrain], x[jTest]
  y_train, y_test = y[iTrain], y[jTest]
  y_train_categorical, y_test_categorical = y_categorical[iTrain], y_categorical[jTest]

  model = CNN_2D()
  
  history = model.fit_generator(datagen.flow(x_train, y_train_categorical, batch_size=18),
                                steps_per_epoch=np.ceil(n_samples/18),
                                epochs=1000,
                                validation_data=(x_test, y_test_categorical),
                                verbose=0, callbacks=[mc])
  
  test_loss, test_acc = model.evaluate(x_test, y_test_categorical, verbose=0)
  array_loss.append(test_loss)
  print("loss: ", test_loss)
  array_acc.append(test_acc)
  print("accuracy: ", test_acc)
    
  probabilidades = model.predict(x_test)
  y_pred = np.argmax(probabilidades, 1) #1=fila
    
  kappa = cohen_kappa_score(y_test, y_pred)
  array_kappa.append(kappa)
  print("kappa: ", kappa)
    
  matriz_confusion = confusion_matrix(y_test, y_pred)
  print("confusion matrix:\n", matriz_confusion)

  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.grid()
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend(['train', 'test'])
  plt.show()
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.grid()
  plt.xlabel('Epochs')
  plt.ylabel('Cross-Entropy')
  plt.legend(['train', 'test'])
  plt.show()
  i += 1
print() 
print("Resultados:")
print("loss:", array_loss)
print("accuracy:", array_acc)
print("kappa:", array_kappa)
fin = time.time()
print("Tiempo:", fin - inicio)
# Out:
# Iteration: 1
#
# Epoch 00001: val_accuracy improved from -inf to 0.25862, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00002: val_accuracy did not improve from 0.25862
#
# Epoch 00003: val_accuracy improved from 0.25862 to 0.27586, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00004: val_accuracy improved from 0.27586 to 0.32759, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00005: val_accuracy improved from 0.32759 to 0.43103, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00006: val_accuracy improved from 0.43103 to 0.46552, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00007: val_accuracy did not improve from 0.46552
#
# Epoch 00008: val_accuracy did not improve from 0.46552
#
# Epoch 00009: val_accuracy improved from 0.46552 to 0.50000, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00010: val_accuracy did not improve from 0.50000
#
# Epoch 00011: val_accuracy did not improve from 0.50000
#
# Epoch 00012: val_accuracy improved from 0.50000 to 0.51724, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00013: val_accuracy did not improve from 0.51724
#
# Epoch 00014: val_accuracy did not improve from 0.51724
#
# Epoch 00015: val_accuracy did not improve from 0.51724
#
# Epoch 00016: val_accuracy did not improve from 0.51724
#
# Epoch 00017: val_accuracy did not improve from 0.51724
#
# Epoch 00018: val_accuracy did not improve from 0.51724
#
# Epoch 00019: val_accuracy did not improve from 0.51724
#
# Epoch 00020: val_accuracy did not improve from 0.51724
#
# Epoch 00021: val_accuracy did not improve from 0.51724
#
# Epoch 00022: val_accuracy did not improve from 0.51724
#
# Epoch 00023: val_accuracy did not improve from 0.51724
#
# Epoch 00024: val_accuracy did not improve from 0.51724
#
# Epoch 00025: val_accuracy did not improve from 0.51724
#
# Epoch 00026: val_accuracy did not improve from 0.51724
#
# Epoch 00027: val_accuracy did not improve from 0.51724
#
# Epoch 00028: val_accuracy did not improve from 0.51724
#
# Epoch 00029: val_accuracy did not improve from 0.51724
#
# Epoch 00030: val_accuracy did not improve from 0.51724
#
# Epoch 00031: val_accuracy did not improve from 0.51724
#
# Epoch 00032: val_accuracy did not improve from 0.51724
#
# Epoch 00033: val_accuracy did not improve from 0.51724
#
# Epoch 00034: val_accuracy did not improve from 0.51724
#
# Epoch 00035: val_accuracy did not improve from 0.51724
#
# Epoch 00036: val_accuracy did not improve from 0.51724
#
# Epoch 00037: val_accuracy did not improve from 0.51724
#
# Epoch 00038: val_accuracy did not improve from 0.51724
#
# Epoch 00039: val_accuracy did not improve from 0.51724
#
# Epoch 00040: val_accuracy did not improve from 0.51724
#
# Epoch 00041: val_accuracy did not improve from 0.51724
#
# Epoch 00042: val_accuracy did not improve from 0.51724
#
# Epoch 00043: val_accuracy did not improve from 0.51724
#
# Epoch 00044: val_accuracy did not improve from 0.51724
#
# Epoch 00045: val_accuracy did not improve from 0.51724
#
# Epoch 00046: val_accuracy did not improve from 0.51724
#
# Epoch 00047: val_accuracy did not improve from 0.51724
#
# Epoch 00048: val_accuracy did not improve from 0.51724
#
# Epoch 00049: val_accuracy did not improve from 0.51724
#
# Epoch 00050: val_accuracy did not improve from 0.51724
#
# Epoch 00051: val_accuracy did not improve from 0.51724
#
# Epoch 00052: val_accuracy did not improve from 0.51724
#
# Epoch 00053: val_accuracy did not improve from 0.51724
#
# Epoch 00054: val_accuracy did not improve from 0.51724
#
# Epoch 00055: val_accuracy did not improve from 0.51724
#
# Epoch 00056: val_accuracy did not improve from 0.51724
#
# Epoch 00057: val_accuracy did not improve from 0.51724
#
# Epoch 00058: val_accuracy did not improve from 0.51724
#
# Epoch 00059: val_accuracy did not improve from 0.51724
#
# Epoch 00060: val_accuracy did not improve from 0.51724
#
# Epoch 00061: val_accuracy did not improve from 0.51724
#
# Epoch 00062: val_accuracy did not improve from 0.51724
#
# Epoch 00063: val_accuracy improved from 0.51724 to 0.53448, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00064: val_accuracy did not improve from 0.53448
#
# Epoch 00065: val_accuracy did not improve from 0.53448
#
# Epoch 00066: val_accuracy did not improve from 0.53448
#
# Epoch 00067: val_accuracy did not improve from 0.53448
#
# Epoch 00068: val_accuracy improved from 0.53448 to 0.55172, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00069: val_accuracy did not improve from 0.55172
#
# Epoch 00070: val_accuracy did not improve from 0.55172
#
# Epoch 00071: val_accuracy did not improve from 0.55172
#
# Epoch 00072: val_accuracy did not improve from 0.55172
#
# Epoch 00073: val_accuracy did not improve from 0.55172
#
# Epoch 00074: val_accuracy did not improve from 0.55172
#
# Epoch 00075: val_accuracy did not improve from 0.55172
#
# Epoch 00076: val_accuracy did not improve from 0.55172
#
# Epoch 00077: val_accuracy did not improve from 0.55172
#
# Epoch 00078: val_accuracy did not improve from 0.55172
#
# Epoch 00079: val_accuracy did not improve from 0.55172
#
# Epoch 00080: val_accuracy did not improve from 0.55172
#
# Epoch 00081: val_accuracy did not improve from 0.55172
#
# Epoch 00082: val_accuracy did not improve from 0.55172
#
# Epoch 00083: val_accuracy did not improve from 0.55172
#
# Epoch 00084: val_accuracy did not improve from 0.55172
#
# Epoch 00085: val_accuracy did not improve from 0.55172
#
# Epoch 00086: val_accuracy did not improve from 0.55172
#
# Epoch 00087: val_accuracy did not improve from 0.55172
#
# Epoch 00088: val_accuracy did not improve from 0.55172
#
# Epoch 00089: val_accuracy did not improve from 0.55172
#
# Epoch 00090: val_accuracy did not improve from 0.55172
#
# Epoch 00091: val_accuracy did not improve from 0.55172
#
# Epoch 00092: val_accuracy did not improve from 0.55172
#
# Epoch 00093: val_accuracy did not improve from 0.55172
#
# Epoch 00094: val_accuracy did not improve from 0.55172
#
# Epoch 00095: val_accuracy did not improve from 0.55172
#
# Epoch 00096: val_accuracy did not improve from 0.55172
#
# Epoch 00097: val_accuracy did not improve from 0.55172
#
# Epoch 00098: val_accuracy did not improve from 0.55172
#
# Epoch 00099: val_accuracy improved from 0.55172 to 0.56897, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00100: val_accuracy improved from 0.56897 to 0.58621, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00101: val_accuracy did not improve from 0.58621
#
# Epoch 00102: val_accuracy did not improve from 0.58621
#
# Epoch 00103: val_accuracy did not improve from 0.58621
#
# Epoch 00104: val_accuracy did not improve from 0.58621
#
# Epoch 00105: val_accuracy did not improve from 0.58621
#
# Epoch 00106: val_accuracy did not improve from 0.58621
#
# Epoch 00107: val_accuracy did not improve from 0.58621
#
# Epoch 00108: val_accuracy did not improve from 0.58621
#
# Epoch 00109: val_accuracy did not improve from 0.58621
#
# Epoch 00110: val_accuracy did not improve from 0.58621
#
# Epoch 00111: val_accuracy did not improve from 0.58621
#
# Epoch 00112: val_accuracy did not improve from 0.58621
#
# Epoch 00113: val_accuracy did not improve from 0.58621
#
# Epoch 00114: val_accuracy did not improve from 0.58621
#
# Epoch 00115: val_accuracy did not improve from 0.58621
#
# Epoch 00116: val_accuracy did not improve from 0.58621
#
# Epoch 00117: val_accuracy did not improve from 0.58621
#
# Epoch 00118: val_accuracy did not improve from 0.58621
#
# Epoch 00119: val_accuracy did not improve from 0.58621
#
# Epoch 00120: val_accuracy did not improve from 0.58621
#
# Epoch 00121: val_accuracy did not improve from 0.58621
#
# Epoch 00122: val_accuracy did not improve from 0.58621
#
# Epoch 00123: val_accuracy did not improve from 0.58621
#
# Epoch 00124: val_accuracy did not improve from 0.58621
#
# Epoch 00125: val_accuracy did not improve from 0.58621
#
# Epoch 00126: val_accuracy did not improve from 0.58621
#
# Epoch 00127: val_accuracy did not improve from 0.58621
#
# Epoch 00128: val_accuracy did not improve from 0.58621
#
# Epoch 00129: val_accuracy improved from 0.58621 to 0.60345, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00130: val_accuracy did not improve from 0.60345
#
# Epoch 00131: val_accuracy did not improve from 0.60345
#
# Epoch 00132: val_accuracy did not improve from 0.60345
#
# Epoch 00133: val_accuracy did not improve from 0.60345
#
# Epoch 00134: val_accuracy did not improve from 0.60345
#
# Epoch 00135: val_accuracy did not improve from 0.60345
#
# Epoch 00136: val_accuracy did not improve from 0.60345
#
# Epoch 00137: val_accuracy did not improve from 0.60345
#
# Epoch 00138: val_accuracy did not improve from 0.60345
#
# Epoch 00139: val_accuracy did not improve from 0.60345
#
# Epoch 00140: val_accuracy did not improve from 0.60345
#
# Epoch 00141: val_accuracy did not improve from 0.60345
#
# Epoch 00142: val_accuracy did not improve from 0.60345
#
# Epoch 00143: val_accuracy did not improve from 0.60345
#
# Epoch 00144: val_accuracy did not improve from 0.60345
#
# Epoch 00145: val_accuracy did not improve from 0.60345
#
# Epoch 00146: val_accuracy did not improve from 0.60345
#
# Epoch 00147: val_accuracy did not improve from 0.60345
#
# Epoch 00148: val_accuracy did not improve from 0.60345
#
# Epoch 00149: val_accuracy did not improve from 0.60345
#
# Epoch 00150: val_accuracy did not improve from 0.60345
#
# Epoch 00151: val_accuracy did not improve from 0.60345
#
# Epoch 00152: val_accuracy did not improve from 0.60345
#
# Epoch 00153: val_accuracy did not improve from 0.60345
#
# Epoch 00154: val_accuracy did not improve from 0.60345
#
# Epoch 00155: val_accuracy did not improve from 0.60345
#
# Epoch 00156: val_accuracy did not improve from 0.60345
#
# Epoch 00157: val_accuracy did not improve from 0.60345
#
# Epoch 00158: val_accuracy did not improve from 0.60345
#
# Epoch 00159: val_accuracy did not improve from 0.60345
#
# Epoch 00160: val_accuracy did not improve from 0.60345
#
# Epoch 00161: val_accuracy did not improve from 0.60345
#
# Epoch 00162: val_accuracy did not improve from 0.60345
#
# Epoch 00163: val_accuracy did not improve from 0.60345
#
# Epoch 00164: val_accuracy did not improve from 0.60345
#
# Epoch 00165: val_accuracy did not improve from 0.60345
#
# Epoch 00166: val_accuracy did not improve from 0.60345
#
# Epoch 00167: val_accuracy did not improve from 0.60345
#
# Epoch 00168: val_accuracy did not improve from 0.60345
#
# Epoch 00169: val_accuracy did not improve from 0.60345
#
# Epoch 00170: val_accuracy did not improve from 0.60345
#
# Epoch 00171: val_accuracy did not improve from 0.60345
#
# Epoch 00172: val_accuracy did not improve from 0.60345
#
# Epoch 00173: val_accuracy did not improve from 0.60345
#
# Epoch 00174: val_accuracy did not improve from 0.60345
#
# Epoch 00175: val_accuracy did not improve from 0.60345
#
# Epoch 00176: val_accuracy did not improve from 0.60345
#
# Epoch 00177: val_accuracy did not improve from 0.60345
#
# Epoch 00178: val_accuracy did not improve from 0.60345
#
# Epoch 00179: val_accuracy did not improve from 0.60345
#
# Epoch 00180: val_accuracy did not improve from 0.60345
#
# Epoch 00181: val_accuracy did not improve from 0.60345
#
# Epoch 00182: val_accuracy did not improve from 0.60345
#
# Epoch 00183: val_accuracy did not improve from 0.60345
#
# Epoch 00184: val_accuracy improved from 0.60345 to 0.63793, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00185: val_accuracy did not improve from 0.63793
#
# Epoch 00186: val_accuracy did not improve from 0.63793
#
# Epoch 00187: val_accuracy did not improve from 0.63793
#
# Epoch 00188: val_accuracy did not improve from 0.63793
#
# Epoch 00189: val_accuracy did not improve from 0.63793
#
# Epoch 00190: val_accuracy did not improve from 0.63793
#
# Epoch 00191: val_accuracy did not improve from 0.63793
#
# Epoch 00192: val_accuracy did not improve from 0.63793
#
# Epoch 00193: val_accuracy did not improve from 0.63793
#
# Epoch 00194: val_accuracy did not improve from 0.63793
#
# Epoch 00195: val_accuracy did not improve from 0.63793
#
# Epoch 00196: val_accuracy did not improve from 0.63793
#
# Epoch 00197: val_accuracy did not improve from 0.63793
#
# Epoch 00198: val_accuracy did not improve from 0.63793
#
# Epoch 00199: val_accuracy did not improve from 0.63793
#
# Epoch 00200: val_accuracy did not improve from 0.63793
#
# Epoch 00201: val_accuracy did not improve from 0.63793
#
# Epoch 00202: val_accuracy did not improve from 0.63793
#
# Epoch 00203: val_accuracy did not improve from 0.63793
#
# Epoch 00204: val_accuracy did not improve from 0.63793
#
# Epoch 00205: val_accuracy did not improve from 0.63793
#
# Epoch 00206: val_accuracy did not improve from 0.63793
#
# Epoch 00207: val_accuracy did not improve from 0.63793
#
# Epoch 00208: val_accuracy did not improve from 0.63793
#
# Epoch 00209: val_accuracy did not improve from 0.63793
#
# Epoch 00210: val_accuracy did not improve from 0.63793
#
# Epoch 00211: val_accuracy did not improve from 0.63793
#
# Epoch 00212: val_accuracy did not improve from 0.63793
#
# Epoch 00213: val_accuracy did not improve from 0.63793
#
# Epoch 00214: val_accuracy did not improve from 0.63793
#
# Epoch 00215: val_accuracy did not improve from 0.63793
#
# Epoch 00216: val_accuracy did not improve from 0.63793
#
# Epoch 00217: val_accuracy did not improve from 0.63793
#
# Epoch 00218: val_accuracy did not improve from 0.63793
#
# Epoch 00219: val_accuracy did not improve from 0.63793
#
# Epoch 00220: val_accuracy did not improve from 0.63793
#
# Epoch 00221: val_accuracy did not improve from 0.63793
#
# Epoch 00222: val_accuracy did not improve from 0.63793
#
# Epoch 00223: val_accuracy did not improve from 0.63793
#
# Epoch 00224: val_accuracy did not improve from 0.63793
#
# Epoch 00225: val_accuracy did not improve from 0.63793
#
# Epoch 00226: val_accuracy did not improve from 0.63793
#
# Epoch 00227: val_accuracy did not improve from 0.63793
#
# Epoch 00228: val_accuracy did not improve from 0.63793
#
# Epoch 00229: val_accuracy did not improve from 0.63793
#
# Epoch 00230: val_accuracy did not improve from 0.63793
#
# Epoch 00231: val_accuracy did not improve from 0.63793
#
# Epoch 00232: val_accuracy did not improve from 0.63793
#
# Epoch 00233: val_accuracy did not improve from 0.63793
#
# Epoch 00234: val_accuracy did not improve from 0.63793
#
# Epoch 00235: val_accuracy did not improve from 0.63793
#
# Epoch 00236: val_accuracy did not improve from 0.63793
#
# Epoch 00237: val_accuracy did not improve from 0.63793
#
# Epoch 00238: val_accuracy did not improve from 0.63793
#
# Epoch 00239: val_accuracy did not improve from 0.63793
#
# Epoch 00240: val_accuracy did not improve from 0.63793
#
# Epoch 00241: val_accuracy did not improve from 0.63793
#
# Epoch 00242: val_accuracy did not improve from 0.63793
#
# Epoch 00243: val_accuracy did not improve from 0.63793
#
# Epoch 00244: val_accuracy did not improve from 0.63793
#
# Epoch 00245: val_accuracy did not improve from 0.63793
#
# Epoch 00246: val_accuracy did not improve from 0.63793
#
# Epoch 00247: val_accuracy did not improve from 0.63793
#
# Epoch 00248: val_accuracy did not improve from 0.63793
#
# Epoch 00249: val_accuracy did not improve from 0.63793
#
# Epoch 00250: val_accuracy did not improve from 0.63793
#
# Epoch 00251: val_accuracy did not improve from 0.63793
#
# Epoch 00252: val_accuracy did not improve from 0.63793
#
# Epoch 00253: val_accuracy did not improve from 0.63793
#
# Epoch 00254: val_accuracy did not improve from 0.63793
#
# Epoch 00255: val_accuracy did not improve from 0.63793
#
# Epoch 00256: val_accuracy did not improve from 0.63793
#
# Epoch 00257: val_accuracy did not improve from 0.63793
#
# Epoch 00258: val_accuracy did not improve from 0.63793
#
# Epoch 00259: val_accuracy did not improve from 0.63793
#
# Epoch 00260: val_accuracy did not improve from 0.63793
#
# Epoch 00261: val_accuracy did not improve from 0.63793
#
# Epoch 00262: val_accuracy did not improve from 0.63793
#
# Epoch 00263: val_accuracy did not improve from 0.63793
#
# Epoch 00264: val_accuracy did not improve from 0.63793
#
# Epoch 00265: val_accuracy did not improve from 0.63793
#
# Epoch 00266: val_accuracy did not improve from 0.63793
#
# Epoch 00267: val_accuracy did not improve from 0.63793
#
# Epoch 00268: val_accuracy did not improve from 0.63793
#
# Epoch 00269: val_accuracy did not improve from 0.63793
#
# Epoch 00270: val_accuracy did not improve from 0.63793
#
# Epoch 00271: val_accuracy did not improve from 0.63793
#
# Epoch 00272: val_accuracy did not improve from 0.63793
#
# Epoch 00273: val_accuracy did not improve from 0.63793
#
# Epoch 00274: val_accuracy did not improve from 0.63793
#
# Epoch 00275: val_accuracy did not improve from 0.63793
#
# Epoch 00276: val_accuracy did not improve from 0.63793
#
# Epoch 00277: val_accuracy did not improve from 0.63793
#
# Epoch 00278: val_accuracy did not improve from 0.63793
#
# Epoch 00279: val_accuracy did not improve from 0.63793
#
# Epoch 00280: val_accuracy did not improve from 0.63793
#
# Epoch 00281: val_accuracy did not improve from 0.63793
#
# Epoch 00282: val_accuracy did not improve from 0.63793
#
# Epoch 00283: val_accuracy did not improve from 0.63793
#
# Epoch 00284: val_accuracy did not improve from 0.63793
#
# Epoch 00285: val_accuracy did not improve from 0.63793
#
# Epoch 00286: val_accuracy did not improve from 0.63793
#
# Epoch 00287: val_accuracy did not improve from 0.63793
#
# Epoch 00288: val_accuracy did not improve from 0.63793
#
# Epoch 00289: val_accuracy did not improve from 0.63793
#
# Epoch 00290: val_accuracy did not improve from 0.63793
#
# Epoch 00291: val_accuracy did not improve from 0.63793
#
# Epoch 00292: val_accuracy did not improve from 0.63793
#
# Epoch 00293: val_accuracy did not improve from 0.63793
#
# Epoch 00294: val_accuracy did not improve from 0.63793
#
# Epoch 00295: val_accuracy did not improve from 0.63793
#
# Epoch 00296: val_accuracy did not improve from 0.63793
#
# Epoch 00297: val_accuracy did not improve from 0.63793
#
# Epoch 00298: val_accuracy did not improve from 0.63793
#
# Epoch 00299: val_accuracy did not improve from 0.63793
#
# Epoch 00300: val_accuracy did not improve from 0.63793
#
# Epoch 00301: val_accuracy did not improve from 0.63793
#
# Epoch 00302: val_accuracy did not improve from 0.63793
#
# Epoch 00303: val_accuracy did not improve from 0.63793
#
# Epoch 00304: val_accuracy did not improve from 0.63793
#
# Epoch 00305: val_accuracy did not improve from 0.63793
#
# Epoch 00306: val_accuracy did not improve from 0.63793
#
# Epoch 00307: val_accuracy did not improve from 0.63793
#
# Epoch 00308: val_accuracy did not improve from 0.63793
#
# Epoch 00309: val_accuracy did not improve from 0.63793
#
# Epoch 00310: val_accuracy did not improve from 0.63793
#
# Epoch 00311: val_accuracy did not improve from 0.63793
#
# Epoch 00312: val_accuracy did not improve from 0.63793
#
# Epoch 00313: val_accuracy did not improve from 0.63793
#
# Epoch 00314: val_accuracy did not improve from 0.63793
#
# Epoch 00315: val_accuracy did not improve from 0.63793
#
# Epoch 00316: val_accuracy did not improve from 0.63793
#
# Epoch 00317: val_accuracy did not improve from 0.63793
#
# Epoch 00318: val_accuracy did not improve from 0.63793
#
# Epoch 00319: val_accuracy did not improve from 0.63793
#
# Epoch 00320: val_accuracy did not improve from 0.63793
#
# Epoch 00321: val_accuracy did not improve from 0.63793
#
# Epoch 00322: val_accuracy did not improve from 0.63793
#
# Epoch 00323: val_accuracy improved from 0.63793 to 0.65517, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00324: val_accuracy did not improve from 0.65517
#
# Epoch 00325: val_accuracy did not improve from 0.65517
#
# Epoch 00326: val_accuracy did not improve from 0.65517
#
# Epoch 00327: val_accuracy did not improve from 0.65517
#
# Epoch 00328: val_accuracy did not improve from 0.65517
#
# Epoch 00329: val_accuracy did not improve from 0.65517
#
# Epoch 00330: val_accuracy did not improve from 0.65517
#
# Epoch 00331: val_accuracy did not improve from 0.65517
#
# Epoch 00332: val_accuracy did not improve from 0.65517
#
# Epoch 00333: val_accuracy did not improve from 0.65517
#
# Epoch 00334: val_accuracy did not improve from 0.65517
#
# Epoch 00335: val_accuracy did not improve from 0.65517
#
# Epoch 00336: val_accuracy did not improve from 0.65517
#
# Epoch 00337: val_accuracy did not improve from 0.65517
#
# Epoch 00338: val_accuracy did not improve from 0.65517
#
# Epoch 00339: val_accuracy did not improve from 0.65517
#
# Epoch 00340: val_accuracy did not improve from 0.65517
#
# Epoch 00341: val_accuracy did not improve from 0.65517
#
# Epoch 00342: val_accuracy did not improve from 0.65517
#
# Epoch 00343: val_accuracy did not improve from 0.65517
#
# Epoch 00344: val_accuracy did not improve from 0.65517
#
# Epoch 00345: val_accuracy did not improve from 0.65517
#
# Epoch 00346: val_accuracy did not improve from 0.65517
#
# Epoch 00347: val_accuracy did not improve from 0.65517
#
# Epoch 00348: val_accuracy did not improve from 0.65517
#
# Epoch 00349: val_accuracy did not improve from 0.65517
#
# Epoch 00350: val_accuracy did not improve from 0.65517
#
# Epoch 00351: val_accuracy did not improve from 0.65517
#
# Epoch 00352: val_accuracy did not improve from 0.65517
#
# Epoch 00353: val_accuracy did not improve from 0.65517
#
# Epoch 00354: val_accuracy did not improve from 0.65517
#
# Epoch 00355: val_accuracy did not improve from 0.65517
#
# Epoch 00356: val_accuracy did not improve from 0.65517
#
# Epoch 00357: val_accuracy did not improve from 0.65517
#
# Epoch 00358: val_accuracy did not improve from 0.65517
#
# Epoch 00359: val_accuracy did not improve from 0.65517
#
# Epoch 00360: val_accuracy did not improve from 0.65517
#
# Epoch 00361: val_accuracy did not improve from 0.65517
#
# Epoch 00362: val_accuracy did not improve from 0.65517
#
# Epoch 00363: val_accuracy did not improve from 0.65517
#
# Epoch 00364: val_accuracy did not improve from 0.65517
#
# Epoch 00365: val_accuracy did not improve from 0.65517
#
# Epoch 00366: val_accuracy did not improve from 0.65517
#
# Epoch 00367: val_accuracy did not improve from 0.65517
#
# Epoch 00368: val_accuracy did not improve from 0.65517
#
# Epoch 00369: val_accuracy did not improve from 0.65517
#
# Epoch 00370: val_accuracy did not improve from 0.65517
#
# Epoch 00371: val_accuracy did not improve from 0.65517
#
# Epoch 00372: val_accuracy did not improve from 0.65517
#
# Epoch 00373: val_accuracy did not improve from 0.65517
#
# Epoch 00374: val_accuracy did not improve from 0.65517
#
# Epoch 00375: val_accuracy did not improve from 0.65517
#
# Epoch 00376: val_accuracy did not improve from 0.65517
#
# Epoch 00377: val_accuracy did not improve from 0.65517
#
# Epoch 00378: val_accuracy did not improve from 0.65517
#
# Epoch 00379: val_accuracy did not improve from 0.65517
#
# Epoch 00380: val_accuracy did not improve from 0.65517
#
# Epoch 00381: val_accuracy did not improve from 0.65517
#
# Epoch 00382: val_accuracy did not improve from 0.65517
#
# Epoch 00383: val_accuracy did not improve from 0.65517
#
# Epoch 00384: val_accuracy did not improve from 0.65517
#
# Epoch 00385: val_accuracy did not improve from 0.65517
#
# Epoch 00386: val_accuracy did not improve from 0.65517
#
# Epoch 00387: val_accuracy did not improve from 0.65517
#
# Epoch 00388: val_accuracy did not improve from 0.65517
#
# Epoch 00389: val_accuracy did not improve from 0.65517
#
# Epoch 00390: val_accuracy did not improve from 0.65517
#
# Epoch 00391: val_accuracy did not improve from 0.65517
#
# Epoch 00392: val_accuracy did not improve from 0.65517
#
# Epoch 00393: val_accuracy did not improve from 0.65517
#
# Epoch 00394: val_accuracy did not improve from 0.65517
#
# Epoch 00395: val_accuracy did not improve from 0.65517
#
# Epoch 00396: val_accuracy did not improve from 0.65517
#
# Epoch 00397: val_accuracy did not improve from 0.65517
#
# Epoch 00398: val_accuracy did not improve from 0.65517
#
# Epoch 00399: val_accuracy did not improve from 0.65517
#
# Epoch 00400: val_accuracy did not improve from 0.65517
#
# Epoch 00401: val_accuracy did not improve from 0.65517
#
# Epoch 00402: val_accuracy did not improve from 0.65517
#
# Epoch 00403: val_accuracy did not improve from 0.65517
#
# Epoch 00404: val_accuracy did not improve from 0.65517
#
# Epoch 00405: val_accuracy did not improve from 0.65517
#
# Epoch 00406: val_accuracy did not improve from 0.65517
#
# Epoch 00407: val_accuracy did not improve from 0.65517
#
# Epoch 00408: val_accuracy did not improve from 0.65517
#
# Epoch 00409: val_accuracy did not improve from 0.65517
#
# Epoch 00410: val_accuracy did not improve from 0.65517
#
# Epoch 00411: val_accuracy did not improve from 0.65517
#
# Epoch 00412: val_accuracy did not improve from 0.65517
#
# Epoch 00413: val_accuracy did not improve from 0.65517
#
# Epoch 00414: val_accuracy did not improve from 0.65517
#
# Epoch 00415: val_accuracy did not improve from 0.65517
#
# Epoch 00416: val_accuracy did not improve from 0.65517
#
# Epoch 00417: val_accuracy did not improve from 0.65517
#
# Epoch 00418: val_accuracy did not improve from 0.65517
#
# Epoch 00419: val_accuracy did not improve from 0.65517
#
# Epoch 00420: val_accuracy did not improve from 0.65517
#
# Epoch 00421: val_accuracy did not improve from 0.65517
#
# Epoch 00422: val_accuracy did not improve from 0.65517
#
# Epoch 00423: val_accuracy did not improve from 0.65517
#
# Epoch 00424: val_accuracy did not improve from 0.65517
#
# Epoch 00425: val_accuracy did not improve from 0.65517
#
# Epoch 00426: val_accuracy did not improve from 0.65517
#
# Epoch 00427: val_accuracy did not improve from 0.65517
#
# Epoch 00428: val_accuracy did not improve from 0.65517
#
# Epoch 00429: val_accuracy did not improve from 0.65517
#
# Epoch 00430: val_accuracy did not improve from 0.65517
#
# Epoch 00431: val_accuracy did not improve from 0.65517
#
# Epoch 00432: val_accuracy did not improve from 0.65517
#
# Epoch 00433: val_accuracy did not improve from 0.65517
#
# Epoch 00434: val_accuracy did not improve from 0.65517
#
# Epoch 00435: val_accuracy did not improve from 0.65517
#
# Epoch 00436: val_accuracy did not improve from 0.65517
#
# Epoch 00437: val_accuracy did not improve from 0.65517
#
# Epoch 00438: val_accuracy did not improve from 0.65517
#
# Epoch 00439: val_accuracy did not improve from 0.65517
#
# Epoch 00440: val_accuracy did not improve from 0.65517
#
# Epoch 00441: val_accuracy did not improve from 0.65517
#
# Epoch 00442: val_accuracy did not improve from 0.65517
#
# Epoch 00443: val_accuracy did not improve from 0.65517
#
# Epoch 00444: val_accuracy did not improve from 0.65517
#
# Epoch 00445: val_accuracy did not improve from 0.65517
#
# Epoch 00446: val_accuracy did not improve from 0.65517
#
# Epoch 00447: val_accuracy did not improve from 0.65517
#
# Epoch 00448: val_accuracy did not improve from 0.65517
#
# Epoch 00449: val_accuracy did not improve from 0.65517
#
# Epoch 00450: val_accuracy did not improve from 0.65517
#
# Epoch 00451: val_accuracy did not improve from 0.65517
#
# Epoch 00452: val_accuracy did not improve from 0.65517
#
# Epoch 00453: val_accuracy did not improve from 0.65517
#
# Epoch 00454: val_accuracy did not improve from 0.65517
#
# Epoch 00455: val_accuracy did not improve from 0.65517
#
# Epoch 00456: val_accuracy did not improve from 0.65517
#
# Epoch 00457: val_accuracy did not improve from 0.65517
#
# Epoch 00458: val_accuracy did not improve from 0.65517
#
# Epoch 00459: val_accuracy did not improve from 0.65517
#
# Epoch 00460: val_accuracy did not improve from 0.65517
#
# Epoch 00461: val_accuracy did not improve from 0.65517
#
# Epoch 00462: val_accuracy did not improve from 0.65517
#
# Epoch 00463: val_accuracy did not improve from 0.65517
#
# Epoch 00464: val_accuracy did not improve from 0.65517
#
# Epoch 00465: val_accuracy did not improve from 0.65517
#
# Epoch 00466: val_accuracy did not improve from 0.65517
#
# Epoch 00467: val_accuracy did not improve from 0.65517
#
# Epoch 00468: val_accuracy did not improve from 0.65517
#
# Epoch 00469: val_accuracy did not improve from 0.65517
#
# Epoch 00470: val_accuracy did not improve from 0.65517
#
# Epoch 00471: val_accuracy did not improve from 0.65517
#
# Epoch 00472: val_accuracy did not improve from 0.65517
#
# Epoch 00473: val_accuracy did not improve from 0.65517
#
# Epoch 00474: val_accuracy did not improve from 0.65517
#
# Epoch 00475: val_accuracy did not improve from 0.65517
#
# Epoch 00476: val_accuracy did not improve from 0.65517
#
# Epoch 00477: val_accuracy did not improve from 0.65517
#
# Epoch 00478: val_accuracy did not improve from 0.65517
#
# Epoch 00479: val_accuracy did not improve from 0.65517
#
# Epoch 00480: val_accuracy did not improve from 0.65517
#
# Epoch 00481: val_accuracy did not improve from 0.65517
#
# Epoch 00482: val_accuracy did not improve from 0.65517
#
# Epoch 00483: val_accuracy did not improve from 0.65517
#
# Epoch 00484: val_accuracy did not improve from 0.65517
#
# Epoch 00485: val_accuracy did not improve from 0.65517
#
# Epoch 00486: val_accuracy did not improve from 0.65517
#
# Epoch 00487: val_accuracy did not improve from 0.65517
#
# Epoch 00488: val_accuracy did not improve from 0.65517
#
# Epoch 00489: val_accuracy did not improve from 0.65517
#
# Epoch 00490: val_accuracy did not improve from 0.65517
#
# Epoch 00491: val_accuracy did not improve from 0.65517
#
# Epoch 00492: val_accuracy did not improve from 0.65517
#
# Epoch 00493: val_accuracy did not improve from 0.65517
#
# Epoch 00494: val_accuracy did not improve from 0.65517
#
# Epoch 00495: val_accuracy did not improve from 0.65517
#
# Epoch 00496: val_accuracy did not improve from 0.65517
#
# Epoch 00497: val_accuracy did not improve from 0.65517
#
# Epoch 00498: val_accuracy did not improve from 0.65517
#
# Epoch 00499: val_accuracy did not improve from 0.65517
#
# Epoch 00500: val_accuracy did not improve from 0.65517
#
# Epoch 00501: val_accuracy did not improve from 0.65517
#
# Epoch 00502: val_accuracy did not improve from 0.65517
#
# Epoch 00503: val_accuracy did not improve from 0.65517
#
# Epoch 00504: val_accuracy did not improve from 0.65517
#
# Epoch 00505: val_accuracy did not improve from 0.65517
#
# Epoch 00506: val_accuracy did not improve from 0.65517
#
# Epoch 00507: val_accuracy did not improve from 0.65517
#
# Epoch 00508: val_accuracy did not improve from 0.65517
#
# Epoch 00509: val_accuracy did not improve from 0.65517
#
# Epoch 00510: val_accuracy did not improve from 0.65517
#
# Epoch 00511: val_accuracy did not improve from 0.65517
#
# Epoch 00512: val_accuracy did not improve from 0.65517
#
# Epoch 00513: val_accuracy improved from 0.65517 to 0.68966, saving model to /content/drive/My Drive/BCI-IV-2a/Modelos/Modelo_STFTDA09_CV.hdf5
#
# Epoch 00514: val_accuracy did not improve from 0.68966
#
# Epoch 00515: val_accuracy did not improve from 0.68966
#
# Epoch 00516: val_accuracy did not improve from 0.68966
#
# Epoch 00517: val_accuracy did not improve from 0.68966
#
# Epoch 00518: val_accuracy did not improve from 0.68966
#
# Epoch 00519: val_accuracy did not improve from 0.68966
#
# Epoch 00520: val_accuracy did not improve from 0.68966
#
# Epoch 00521: val_accuracy did not improve from 0.68966
#
# Epoch 00522: val_accuracy did not improve from 0.68966
#
# Epoch 00523: val_accuracy did not improve from 0.68966
#
# Epoch 00524: val_accuracy did not improve from 0.68966
#
# Epoch 00525: val_accuracy did not improve from 0.68966
#
# Epoch 00526: val_accuracy did not improve from 0.68966
#
# Epoch 00527: val_accuracy did not improve from 0.68966
#
# Epoch 00528: val_accuracy did not improve from 0.68966
#
# Epoch 00529: val_accuracy did not improve from 0.68966
#
# Epoch 00530: val_accuracy did not improve from 0.68966
#
# Epoch 00531: val_accuracy did not improve from 0.68966
#
# Epoch 00532: val_accuracy did not improve from 0.68966
#
# Epoch 00533: val_accuracy did not improve from 0.68966
#
# Epoch 00534: val_accuracy did not improve from 0.68966
#
# Epoch 00535: val_accuracy did not improve from 0.68966
#
# Epoch 00536: val_accuracy did not improve from 0.68966
#
# Epoch 00537: val_accuracy did not improve from 0.68966
#
# Epoch 00538: val_accuracy did not improve from 0.68966
#
# Epoch 00539: val_accuracy did not improve from 0.68966
#
# Epoch 00540: val_accuracy did not improve from 0.68966
#
# Epoch 00541: val_accuracy did not improve from 0.68966
#
# Epoch 00542: val_accuracy did not improve from 0.68966
#
# Epoch 00543: val_accuracy did not improve from 0.68966
#
# Epoch 00544: val_accuracy did not improve from 0.68966
#
# Epoch 00545: val_accuracy did not improve from 0.68966
#
# Epoch 00546: val_accuracy did not improve from 0.68966
#
# Epoch 00547: val_accuracy did not improve from 0.68966
#
# Epoch 00548: val_accuracy did not improve from 0.68966
#
# Epoch 00549: val_accuracy did not improve from 0.68966
#
# Epoch 00550: val_accuracy did not improve from 0.68966
#
# Epoch 00551: val_accuracy did not improve from 0.68966
#
# Epoch 00552: val_accuracy did not improve from 0.68966
#
# Epoch 00553: val_accuracy did not improve from 0.68966
#
# Epoch 00554: val_accuracy did not improve from 0.68966
#
# Epoch 00555: val_accuracy did not improve from 0.68966
#
# Epoch 00556: val_accuracy did not improve from 0.68966
#
# Epoch 00557: val_accuracy did not improve from 0.68966
#
# Epoch 00558: val_accuracy did not improve from 0.68966
#
# Epoch 00559: val_accuracy did not improve from 0.68966
#
# Epoch 00560: val_accuracy did not improve from 0.68966
#
# Epoch 00561: val_accuracy did not improve from 0.68966
#
# Epoch 00562: val_accuracy did not improve from 0.68966
#
# Epoch 00563: val_accuracy did not improve from 0.68966
#
# Epoch 00564: val_accuracy did not improve from 0.68966
#
# Epoch 00565: val_accuracy did not improve from 0.68966
#
# Epoch 00566: val_accuracy did not improve from 0.68966
#
# Epoch 00567: val_accuracy did not improve from 0.68966
#
# Epoch 00568: val_accuracy did not improve from 0.68966
#
# Epoch 00569: val_accuracy did not improve from 0.68966
#
# Epoch 00570: val_accuracy did not improve from 0.68966
#
# Epoch 00571: val_accuracy did not improve from 0.68966
#
# Epoch 00572: val_accuracy did not improve from 0.68966
#
# Epoch 00573: val_accuracy did not improve from 0.68966
#
# Epoch 00574: val_accuracy did not improve from 0.68966
#
# Epoch 00575: val_accuracy did not improve from 0.68966
#
# Epoch 00576: val_accuracy did not improve from 0.68966
#
# Epoch 00577: val_accuracy did not improve from 0.68966
#
# Epoch 00578: val_accuracy did not improve from 0.68966
#
# Epoch 00579: val_accuracy did not improve from 0.68966
#
# Epoch 00580: val_accuracy did not improve from 0.68966
#
# Epoch 00581: val_accuracy did not improve from 0.68966
#
# Epoch 00582: val_accuracy did not improve from 0.68966
#
# Epoch 00583: val_accuracy did not improve from 0.68966
#
# Epoch 00584: val_accuracy did not improve from 0.68966
#
# Epoch 00585: val_accuracy did not improve from 0.68966
#
# Epoch 00586: val_accuracy did not improve from 0.68966
#
# Epoch 00587: val_accuracy did not improve from 0.68966
#
# Epoch 00588: val_accuracy did not improve from 0.68966
#
# Epoch 00589: val_accuracy did not improve from 0.68966
#
# Epoch 00590: val_accuracy did not improve from 0.68966
#
# Epoch 00591: val_accuracy did not improve from 0.68966
#
# Epoch 00592: val_accuracy did not improve from 0.68966
#
# Epoch 00593: val_accuracy did not improve from 0.68966
#
# Epoch 00594: val_accuracy did not improve from 0.68966
#
# Epoch 00595: val_accuracy did not improve from 0.68966
#
# Epoch 00596: val_accuracy did not improve from 0.68966
#
# Epoch 00597: val_accuracy did not improve from 0.68966
#
# Epoch 00598: val_accuracy did not improve from 0.68966
#
# Epoch 00599: val_accuracy did not improve from 0.68966
#
# Epoch 00600: val_accuracy did not improve from 0.68966
#
# Epoch 00601: val_accuracy did not improve from 0.68966
#
# Epoch 00602: val_accuracy did not improve from 0.68966
#
# Epoch 00603: val_accuracy did not improve from 0.68966
#
# Epoch 00604: val_accuracy did not improve from 0.68966
#
# Epoch 00605: val_accuracy did not improve from 0.68966
#
# Epoch 00606: val_accuracy did not improve from 0.68966
#
# Epoch 00607: val_accuracy did not improve from 0.68966
#
# Epoch 00608: val_accuracy did not improve from 0.68966
#
# Epoch 00609: val_accuracy did not improve from 0.68966
#
# Epoch 00610: val_accuracy did not improve from 0.68966
#
# Epoch 00611: val_accuracy did not improve from 0.68966
#
# Epoch 00612: val_accuracy did not improve from 0.68966
#
# Epoch 00613: val_accuracy did not improve from 0.68966
#
# Epoch 00614: val_accuracy did not improve from 0.68966
#
# Epoch 00615: val_accuracy did not improve from 0.68966
#
# Epoch 00616: val_accuracy did not improve from 0.68966
#
# Epoch 00617: val_accuracy did not improve from 0.68966
#
# Epoch 00618: val_accuracy did not improve from 0.68966
#
# Epoch 00619: val_accuracy did not improve from 0.68966
#
# Epoch 00620: val_accuracy did not improve from 0.68966
#
# Epoch 00621: val_accuracy did not improve from 0.68966
#
# Epoch 00622: val_accuracy did not improve from 0.68966
#
# Epoch 00623: val_accuracy did not improve from 0.68966
#
# Epoch 00624: val_accuracy did not improve from 0.68966
#
# Epoch 00625: val_accuracy did not improve from 0.68966
#
# Epoch 00626: val_accuracy did not improve from 0.68966
#
# Epoch 00627: val_accuracy did not improve from 0.68966
#
# Epoch 00628: val_accuracy did not improve from 0.68966
#
# Epoch 00629: val_accuracy did not improve from 0.68966
#
# Epoch 00630: val_accuracy did not improve from 0.68966
#
# Epoch 00631: val_accuracy did not improve from 0.68966
#
# Epoch 00632: val_accuracy did not improve from 0.68966
#
# Epoch 00633: val_accuracy did not improve from 0.68966
#
# Epoch 00634: val_accuracy did not improve from 0.68966
#
# Epoch 00635: val_accuracy did not improve from 0.68966
#
# Epoch 00636: val_accuracy did not improve from 0.68966
#
# Epoch 00637: val_accuracy did not improve from 0.68966
#
# Epoch 00638: val_accuracy did not improve from 0.68966
#
# Epoch 00639: val_accuracy did not improve from 0.68966
#
# Epoch 00640: val_accuracy did not improve from 0.68966
#
# Epoch 00641: val_accuracy did not improve from 0.68966
#
# Epoch 00642: val_accuracy did not improve from 0.68966
#
# Epoch 00643: val_accuracy did not improve from 0.68966
#
# Epoch 00644: val_accuracy did not improve from 0.68966
#
# Epoch 00645: val_accuracy did not improve from 0.68966
#
# Epoch 00646: val_accuracy did not improve from 0.68966
#
# Epoch 00647: val_accuracy did not improve from 0.68966
#
# Epoch 00648: val_accuracy did not improve from 0.68966
#
# Epoch 00649: val_accuracy did not improve from 0.68966
#
# Epoch 00650: val_accuracy did not improve from 0.68966
#
# Epoch 00651: val_accuracy did not improve from 0.68966
#
# Epoch 00652: val_accuracy did not improve from 0.68966
#
# Epoch 00653: val_accuracy did not improve from 0.68966
#
# Epoch 00654: val_accuracy did not improve from 0.68966
#
# Epoch 00655: val_accuracy did not improve from 0.68966
#
# Epoch 00656: val_accuracy did not improve from 0.68966
#
# Epoch 00657: val_accuracy did not improve from 0.68966
#
# Epoch 00658: val_accuracy did not improve from 0.68966
#
# Epoch 00659: val_accuracy did not improve from 0.68966
#
# Epoch 00660: val_accuracy did not improve from 0.68966
#
# Epoch 00661: val_accuracy did not improve from 0.68966
#
# Epoch 00662: val_accuracy did not improve from 0.68966
#
# Epoch 00663: val_accuracy did not improve from 0.68966
#
# Epoch 00664: val_accuracy did not improve from 0.68966
#
# Epoch 00665: val_accuracy did not improve from 0.68966
#
# Epoch 00666: val_accuracy did not improve from 0.68966
#
# Epoch 00667: val_accuracy did not improve from 0.68966
#
# Epoch 00668: val_accuracy did not improve from 0.68966
#
# Epoch 00669: val_accuracy did not improve from 0.68966
#
# Epoch 00670: val_accuracy did not improve from 0.68966
#
# Epoch 00671: val_accuracy did not improve from 0.68966
#
# Epoch 00672: val_accuracy did not improve from 0.68966
#
# Epoch 00673: val_accuracy did not improve from 0.68966
#
# Epoch 00674: val_accuracy did not improve from 0.68966
#
# Epoch 00675: val_accuracy did not improve from 0.68966
#
# Epoch 00676: val_accuracy did not improve from 0.68966
#
# Epoch 00677: val_accuracy did not improve from 0.68966
#
# Epoch 00678: val_accuracy did not improve from 0.68966
#
# Epoch 00679: val_accuracy did not improve from 0.68966
#
# Epoch 00680: val_accuracy did not improve from 0.68966
#
# Epoch 00681: val_accuracy did not improve from 0.68966
#
# Epoch 00682: val_accuracy did not improve from 0.68966
#
# Epoch 00683: val_accuracy did not improve from 0.68966
#
# Epoch 00684: val_accuracy did not improve from 0.68966
#
# Epoch 00685: val_accuracy did not improve from 0.68966
#
# Epoch 00686: val_accuracy did not improve from 0.68966
#
# Epoch 00687: val_accuracy did not improve from 0.68966
#
# Epoch 00688: val_accuracy did not improve from 0.68966
#
# Epoch 00689: val_accuracy did not improve from 0.68966
#
# Epoch 00690: val_accuracy did not improve from 0.68966
#
# Epoch 00691: val_accuracy did not improve from 0.68966
#
# Epoch 00692: val_accuracy did not improve from 0.68966
#
# Epoch 00693: val_accuracy did not improve from 0.68966
#
# Epoch 00694: val_accuracy did not improve from 0.68966
#
# Epoch 00695: val_accuracy did not improve from 0.68966
#
# Epoch 00696: val_accuracy did not improve from 0.68966
#
# Epoch 00697: val_accuracy did not improve from 0.68966
#
# Epoch 00698: val_accuracy did not improve from 0.68966
#
# Epoch 00699: val_accuracy did not improve from 0.68966
#
# Epoch 00700: val_accuracy did not improve from 0.68966
#
# Epoch 00701: val_accuracy did not improve from 0.68966
#
# Epoch 00702: val_accuracy did not improve from 0.68966
#
# Epoch 00703: val_accuracy did not improve from 0.68966
#
# Epoch 00704: val_accuracy did not improve from 0.68966
#
# Epoch 00705: val_accuracy did not improve from 0.68966
#
# Epoch 00706: val_accuracy did not improve from 0.68966
#
# Epoch 00707: val_accuracy did not improve from 0.68966
#
# Epoch 00708: val_accuracy did not improve from 0.68966
#
# Epoch 00709: val_accuracy did not improve from 0.68966
#
# Epoch 00710: val_accuracy did not improve from 0.68966
#
# Epoch 00711: val_accuracy did not improve from 0.68966
#
# Epoch 00712: val_accuracy did not improve from 0.68966
#
# Epoch 00713: val_accuracy did not improve from 0.68966
#
# Epoch 00714: val_accuracy did not improve from 0.68966
#
# Epoch 00715: val_accuracy did not improve from 0.68966
#
# Epoch 00716: val_accuracy did not improve from 0.68966
#
# Epoch 00717: val_accuracy did not improve from 0.68966
#
# Epoch 00718: val_accuracy did not improve from 0.68966
#
# Epoch 00719: val_accuracy did not improve from 0.68966
#
# Epoch 00720: val_accuracy did not improve from 0.68966
#
# Epoch 00721: val_accuracy did not improve from 0.68966
#
# Epoch 00722: val_accuracy did not improve from 0.68966
#
# Epoch 00723: val_accuracy did not improve from 0.68966
#
# Epoch 00724: val_accuracy did not improve from 0.68966
#
# Epoch 00725: val_accuracy did not improve from 0.68966
#
# Epoch 00726: val_accuracy did not improve from 0.68966
#
# Epoch 00727: val_accuracy did not improve from 0.68966
#
# Epoch 00728: val_accuracy did not improve from 0.68966
#
# Epoch 00729: val_accuracy did not improve from 0.68966
#
# Epoch 00730: val_accuracy did not improve from 0.68966
#
# Epoch 00731: val_accuracy did not improve from 0.68966
#
# Epoch 00732: val_accuracy did not improve from 0.68966
#
# Epoch 00733: val_accuracy did not improve from 0.68966
#
# Epoch 00734: val_accuracy did not improve from 0.68966
#
# Epoch 00735: val_accuracy did not improve from 0.68966
#
# Epoch 00736: val_accuracy did not improve from 0.68966
#
# Epoch 00737: val_accuracy did not improve from 0.68966
#
# Epoch 00738: val_accuracy did not improve from 0.68966
#
# Epoch 00739: val_accuracy did not improve from 0.68966
#
# Epoch 00740: val_accuracy did not improve from 0.68966
#
# Epoch 00741: val_accuracy did not improve from 0.68966
#
# Epoch 00742: val_accuracy did not improve from 0.68966
#
# Epoch 00743: val_accuracy did not improve from 0.68966
#
# Epoch 00744: val_accuracy did not improve from 0.68966
#
# Epoch 00745: val_accuracy did not improve from 0.68966
#
# Epoch 00746: val_accuracy did not improve from 0.68966
#
# Epoch 00747: val_accuracy did not improve from 0.68966
#
# Epoch 00748: val_accuracy did not improve from 0.68966
#
# Epoch 00749: val_accuracy did not improve from 0.68966
#
# Epoch 00750: val_accuracy did not improve from 0.68966
#
# Epoch 00751: val_accuracy did not improve from 0.68966
#
# Epoch 00752: val_accuracy did not improve from 0.68966
#
# Epoch 00753: val_accuracy did not improve from 0.68966
#
# Epoch 00754: val_accuracy did not improve from 0.68966
#
# Epoch 00755: val_accuracy did not improve from 0.68966
#
# Epoch 00756: val_accuracy did not improve from 0.68966
#
# Epoch 00757: val_accuracy did not improve from 0.68966
#
# Epoch 00758: val_accuracy did not improve from 0.68966
#
# Epoch 00759: val_accuracy did not improve from 0.68966
#
# Epoch 00760: val_accuracy did not improve from 0.68966
#
# Epoch 00761: val_accuracy did not improve from 0.68966
#
# Epoch 00762: val_accuracy did not improve from 0.68966
#
# Epoch 00763: val_accuracy did not improve from 0.68966
#
# Epoch 00764: val_accuracy did not improve from 0.68966
#
# Epoch 00765: val_accuracy did not improve from 0.68966
#
# Epoch 00766: val_accuracy did not improve from 0.68966
#
# Epoch 00767: val_accuracy did not improve from 0.68966
#
# Epoch 00768: val_accuracy did not improve from 0.68966
#
# Epoch 00769: val_accuracy did not improve from 0.68966
#
# Epoch 00770: val_accuracy did not improve from 0.68966
#
# Epoch 00771: val_accuracy did not improve from 0.68966
#
# Epoch 00772: val_accuracy did not improve from 0.68966
#
# Epoch 00773: val_accuracy did not improve from 0.68966
#
# Epoch 00774: val_accuracy did not improve from 0.68966
#
# Epoch 00775: val_accuracy did not improve from 0.68966
#
# Epoch 00776: val_accuracy did not improve from 0.68966
#
# Epoch 00777: val_accuracy did not improve from 0.68966
#
# Epoch 00778: val_accuracy did not improve from 0.68966
#
# Epoch 00779: val_accuracy did not improve from 0.68966
#
# Epoch 00780: val_accuracy did not improve from 0.68966
#
# Epoch 00781: val_accuracy did not improve from 0.68966
#
# Epoch 00782: val_accuracy did not improve from 0.68966
#
# Epoch 00783: val_accuracy did not improve from 0.68966
#
# Epoch 00784: val_accuracy did not improve from 0.68966
#
# Epoch 00785: val_accuracy did not improve from 0.68966
#
# Epoch 00786: val_accuracy did not improve from 0.68966
#
# Epoch 00787: val_accuracy did not improve from 0.68966
#
# Epoch 00788: val_accuracy did not improve from 0.68966
#
# Epoch 00789: val_accuracy did not improve from 0.68966
#
# Epoch 00790: val_accuracy did not improve from 0.68966
#
# Epoch 00791: val_accuracy did not improve from 0.68966
#
# Epoch 00792: val_accuracy did not improve from 0.68966
#
# Epoch 00793: val_accuracy did not improve from 0.68966
#
# Epoch 00794: val_accuracy did not improve from 0.68966
#
# Epoch 00795: val_accuracy did not improve from 0.68966
#
# Epoch 00796: val_accuracy did not improve from 0.68966
#
# Epoch 00797: val_accuracy did not improve from 0.68966
#
# Epoch 00798: val_accuracy did not improve from 0.68966
#
# Epoch 00799: val_accuracy did not improve from 0.68966
#
# Epoch 00800: val_accuracy did not improve from 0.68966
#
# Epoch 00801: val_accuracy did not improve from 0.68966
#
# Epoch 00802: val_accuracy did not improve from 0.68966
#
# Epoch 00803: val_accuracy did not improve from 0.68966
#
# Epoch 00804: val_accuracy did not improve from 0.68966
#
# Epoch 00805: val_accuracy did not improve from 0.68966
#
# Epoch 00806: val_accuracy did not improve from 0.68966
#
# Epoch 00807: val_accuracy did not improve from 0.68966
#
# Epoch 00808: val_accuracy did not improve from 0.68966
#
# Epoch 00809: val_accuracy did not improve from 0.68966
#
# Epoch 00810: val_accuracy did not improve from 0.68966
#
# Epoch 00811: val_accuracy did not improve from 0.68966
#
# Epoch 00812: val_accuracy did not improve from 0.68966
#
# Epoch 00813: val_accuracy did not improve from 0.68966
#
# Epoch 00814: val_accuracy did not improve from 0.68966
#
# Epoch 00815: val_accuracy did not improve from 0.68966
#
# Epoch 00816: val_accuracy did not improve from 0.68966
#
# Epoch 00817: val_accuracy did not improve from 0.68966
#
# Epoch 00818: val_accuracy did not improve from 0.68966
#
# Epoch 00819: val_accuracy did not improve from 0.68966
#
# Epoch 00820: val_accuracy did not improve from 0.68966
#
# Epoch 00821: val_accuracy did not improve from 0.68966
#
# Epoch 00822: val_accuracy did not improve from 0.68966
#
# Epoch 00823: val_accuracy did not improve from 0.68966
#
# Epoch 00824: val_accuracy did not improve from 0.68966
#
# Epoch 00825: val_accuracy did not improve from 0.68966
#
# Epoch 00826: val_accuracy did not improve from 0.68966
#
# Epoch 00827: val_accuracy did not improve from 0.68966
#
# Epoch 00828: val_accuracy did not improve from 0.68966
#
# Epoch 00829: val_accuracy did not improve from 0.68966
#
# Epoch 00830: val_accuracy did not improve from 0.68966
#
# Epoch 00831: val_accuracy did not improve from 0.68966
#
# Epoch 00832: val_accuracy did not improve from 0.68966
#
# Epoch 00833: val_accuracy did not improve from 0.68966
#
# ...
#
# Epoch 00731: val_accuracy did not improve from 0.89655
#
# Epoch 00732: val_accuracy did not improve from 0.89655
#
# Epoch 00733: val_accuracy did not improve from 0.89655
#
# Epoch 00734: val_accuracy did not improve from 0.89655
#
# Epoch 00735: val_accuracy did not improve from 0.89655
#
# Epoch 00736: val_accuracy did not improve from 0.89655
#
# Epoch 00737: val_accuracy did not improve from 0.89655
#
# Epoch 00738: val_accuracy did not improve from 0.89655
#
# Epoch 00739: val_accuracy did not improve from 0.89655
#
# Epoch 00740: val_accuracy did not improve from 0.89655
#
# Epoch 00741: val_accuracy did not improve from 0.89655
#
# Epoch 00742: val_accuracy did not improve from 0.89655
#
# Epoch 00743: val_accuracy did not improve from 0.89655
#
# Epoch 00744: val_accuracy did not improve from 0.89655
#
# Epoch 00745: val_accuracy did not improve from 0.89655
#
# Epoch 00746: val_accuracy did not improve from 0.89655
#
# Epoch 00747: val_accuracy did not improve from 0.89655
#
# Epoch 00748: val_accuracy did not improve from 0.89655
#
# Epoch 00749: val_accuracy did not improve from 0.89655
#
# Epoch 00750: val_accuracy did not improve from 0.89655
#
# Epoch 00751: val_accuracy did not improve from 0.89655
#
# Epoch 00752: val_accuracy did not improve from 0.89655
#
# Epoch 00753: val_accuracy did not improve from 0.89655
#
# Epoch 00754: val_accuracy did not improve from 0.89655
#
# Epoch 00755: val_accuracy did not improve from 0.89655
#
# Epoch 00756: val_accuracy did not improve from 0.89655
#
# Epoch 00757: val_accuracy did not improve from 0.89655
#
# Epoch 00758: val_accuracy did not improve from 0.89655
#
# Epoch 00759: val_accuracy did not improve from 0.89655
#
# Epoch 00760: val_accuracy did not improve from 0.89655
#
# Epoch 00761: val_accuracy did not improve from 0.89655
#
# Epoch 00762: val_accuracy did not improve from 0.89655
#
# Epoch 00763: val_accuracy did not improve from 0.89655
#
# Epoch 00764: val_accuracy did not improve from 0.89655
#
# Epoch 00765: val_accuracy did not improve from 0.89655
#
# Epoch 00766: val_accuracy did not improve from 0.89655
#
# Epoch 00767: val_accuracy did not improve from 0.89655
#
# Epoch 00768: val_accuracy did not improve from 0.89655
#
# Epoch 00769: val_accuracy did not improve from 0.89655
#
# Epoch 00770: val_accuracy did not improve from 0.89655
#
# Epoch 00771: val_accuracy did not improve from 0.89655
#
# Epoch 00772: val_accuracy did not improve from 0.89655
#
# Epoch 00773: val_accuracy did not improve from 0.89655
#
# Epoch 00774: val_accuracy did not improve from 0.89655
#
# Epoch 00775: val_accuracy did not improve from 0.89655
#
# Epoch 00776: val_accuracy did not improve from 0.89655
#
# Epoch 00777: val_accuracy did not improve from 0.89655
#
# Epoch 00778: val_accuracy did not improve from 0.89655
#
# Epoch 00779: val_accuracy did not improve from 0.89655
#
# Epoch 00780: val_accuracy did not improve from 0.89655
#
# Epoch 00781: val_accuracy did not improve from 0.89655
#
# Epoch 00782: val_accuracy did not improve from 0.89655
#
# Epoch 00783: val_accuracy did not improve from 0.89655
#
# Epoch 00784: val_accuracy did not improve from 0.89655
#
# Epoch 00785: val_accuracy did not improve from 0.89655
#
# Epoch 00786: val_accuracy did not improve from 0.89655
#
# Epoch 00787: val_accuracy did not improve from 0.89655
#
# Epoch 00788: val_accuracy did not improve from 0.89655
#
# Epoch 00789: val_accuracy did not improve from 0.89655
#
# Epoch 00790: val_accuracy did not improve from 0.89655
#
# Epoch 00791: val_accuracy did not improve from 0.89655
#
# Epoch 00792: val_accuracy did not improve from 0.89655
#
# Epoch 00793: val_accuracy did not improve from 0.89655
#
# Epoch 00794: val_accuracy did not improve from 0.89655
#
# Epoch 00795: val_accuracy did not improve from 0.89655
#
# Epoch 00796: val_accuracy did not improve from 0.89655
#
# Epoch 00797: val_accuracy did not improve from 0.89655
#
# Epoch 00798: val_accuracy did not improve from 0.89655
#
# Epoch 00799: val_accuracy did not improve from 0.89655
#
# Epoch 00800: val_accuracy did not improve from 0.89655
#
# Epoch 00801: val_accuracy did not improve from 0.89655
#
# Epoch 00802: val_accuracy did not improve from 0.89655
#
# Epoch 00803: val_accuracy did not improve from 0.89655
#
# Epoch 00804: val_accuracy did not improve from 0.89655
#
# Epoch 00805: val_accuracy did not improve from 0.89655
#
# Epoch 00806: val_accuracy did not improve from 0.89655
#
# Epoch 00807: val_accuracy did not improve from 0.89655
#
# Epoch 00808: val_accuracy did not improve from 0.89655
#
# Epoch 00809: val_accuracy did not improve from 0.89655
#
# Epoch 00810: val_accuracy did not improve from 0.89655
#
# Epoch 00811: val_accuracy did not improve from 0.89655
#
# Epoch 00812: val_accuracy did not improve from 0.89655
#
# Epoch 00813: val_accuracy did not improve from 0.89655
#
# Epoch 00814: val_accuracy did not improve from 0.89655
#
# Epoch 00815: val_accuracy did not improve from 0.89655
#
# Epoch 00816: val_accuracy did not improve from 0.89655
#
# Epoch 00817: val_accuracy did not improve from 0.89655
#
# Epoch 00818: val_accuracy did not improve from 0.89655
#
# Epoch 00819: val_accuracy did not improve from 0.89655
#
# Epoch 00820: val_accuracy did not improve from 0.89655
#
# Epoch 00821: val_accuracy did not improve from 0.89655
#
# Epoch 00822: val_accuracy did not improve from 0.89655
#
# Epoch 00823: val_accuracy did not improve from 0.89655
#
# Epoch 00824: val_accuracy did not improve from 0.89655
#
# Epoch 00825: val_accuracy did not improve from 0.89655
#
# Epoch 00826: val_accuracy did not improve from 0.89655
#
# Epoch 00827: val_accuracy did not improve from 0.89655
#
# Epoch 00828: val_accuracy did not improve from 0.89655
#
# Epoch 00829: val_accuracy did not improve from 0.89655
#
# Epoch 00830: val_accuracy did not improve from 0.89655
#
# Epoch 00831: val_accuracy did not improve from 0.89655
#
# Epoch 00832: val_accuracy did not improve from 0.89655
#
# Epoch 00833: val_accuracy did not improve from 0.89655
#
# Epoch 00834: val_accuracy did not improve from 0.89655
#
# Epoch 00835: val_accuracy did not improve from 0.89655
#
# Epoch 00836: val_accuracy did not improve from 0.89655
#
# Epoch 00837: val_accuracy did not improve from 0.89655
#
# Epoch 00838: val_accuracy did not improve from 0.89655
#
# Epoch 00839: val_accuracy did not improve from 0.89655
#
# Epoch 00840: val_accuracy did not improve from 0.89655
#
# Epoch 00841: val_accuracy did not improve from 0.89655
#
# Epoch 00842: val_accuracy did not improve from 0.89655
#
# Epoch 00843: val_accuracy did not improve from 0.89655
#
# Epoch 00844: val_accuracy did not improve from 0.89655
#
# Epoch 00845: val_accuracy did not improve from 0.89655
#
# Epoch 00846: val_accuracy did not improve from 0.89655
#
# Epoch 00847: val_accuracy did not improve from 0.89655
#
# Epoch 00848: val_accuracy did not improve from 0.89655
#
# Epoch 00849: val_accuracy did not improve from 0.89655
#
# Epoch 00850: val_accuracy did not improve from 0.89655
#
# Epoch 00851: val_accuracy did not improve from 0.89655
#
# Epoch 00852: val_accuracy did not improve from 0.89655
#
# Epoch 00853: val_accuracy did not improve from 0.89655
#
# Epoch 00854: val_accuracy did not improve from 0.89655
#
# Epoch 00855: val_accuracy did not improve from 0.89655
#
# Epoch 00856: val_accuracy did not improve from 0.89655
#
# Epoch 00857: val_accuracy did not improve from 0.89655
#
# Epoch 00858: val_accuracy did not improve from 0.89655
#
# Epoch 00859: val_accuracy did not improve from 0.89655
#
# Epoch 00860: val_accuracy did not improve from 0.89655
#
# Epoch 00861: val_accuracy did not improve from 0.89655
#
# Epoch 00862: val_accuracy did not improve from 0.89655
#
# Epoch 00863: val_accuracy did not improve from 0.89655
#
# Epoch 00864: val_accuracy did not improve from 0.89655
#
# Epoch 00865: val_accuracy did not improve from 0.89655
#
# Epoch 00866: val_accuracy did not improve from 0.89655
#
# Epoch 00867: val_accuracy did not improve from 0.89655
#
# Epoch 00868: val_accuracy did not improve from 0.89655
#
# Epoch 00869: val_accuracy did not improve from 0.89655
#
# Epoch 00870: val_accuracy did not improve from 0.89655
#
# Epoch 00871: val_accuracy did not improve from 0.89655
#
# Epoch 00872: val_accuracy did not improve from 0.89655
#
# Epoch 00873: val_accuracy did not improve from 0.89655
#
# Epoch 00874: val_accuracy did not improve from 0.89655
#
# Epoch 00875: val_accuracy did not improve from 0.89655
#
# Epoch 00876: val_accuracy did not improve from 0.89655
#
# Epoch 00877: val_accuracy did not improve from 0.89655
#
# Epoch 00878: val_accuracy did not improve from 0.89655
#
# Epoch 00879: val_accuracy did not improve from 0.89655
#
# Epoch 00880: val_accuracy did not improve from 0.89655
#
# Epoch 00881: val_accuracy did not improve from 0.89655
#
# Epoch 00882: val_accuracy did not improve from 0.89655
#
# Epoch 00883: val_accuracy did not improve from 0.89655
#
# Epoch 00884: val_accuracy did not improve from 0.89655
#
# Epoch 00885: val_accuracy did not improve from 0.89655
#
# Epoch 00886: val_accuracy did not improve from 0.89655
#
# Epoch 00887: val_accuracy did not improve from 0.89655
#
# Epoch 00888: val_accuracy did not improve from 0.89655
#
# Epoch 00889: val_accuracy did not improve from 0.89655
#
# Epoch 00890: val_accuracy did not improve from 0.89655
#
# Epoch 00891: val_accuracy did not improve from 0.89655
#
# Epoch 00892: val_accuracy did not improve from 0.89655
#
# Epoch 00893: val_accuracy did not improve from 0.89655
#
# Epoch 00894: val_accuracy did not improve from 0.89655
#
# Epoch 00895: val_accuracy did not improve from 0.89655
#
# Epoch 00896: val_accuracy did not improve from 0.89655
#
# Epoch 00897: val_accuracy did not improve from 0.89655
#
# Epoch 00898: val_accuracy did not improve from 0.89655
#
# Epoch 00899: val_accuracy did not improve from 0.89655
#
# Epoch 00900: val_accuracy did not improve from 0.89655
#
# Epoch 00901: val_accuracy did not improve from 0.89655
#
# Epoch 00902: val_accuracy did not improve from 0.89655
#
# Epoch 00903: val_accuracy did not improve from 0.89655
#
# Epoch 00904: val_accuracy did not improve from 0.89655
#
# Epoch 00905: val_accuracy did not improve from 0.89655
#
# Epoch 00906: val_accuracy did not improve from 0.89655
#
# Epoch 00907: val_accuracy did not improve from 0.89655
#
# Epoch 00908: val_accuracy did not improve from 0.89655
#
# Epoch 00909: val_accuracy did not improve from 0.89655
#
# Epoch 00910: val_accuracy did not improve from 0.89655
#
# Epoch 00911: val_accuracy did not improve from 0.89655
#
# Epoch 00912: val_accuracy did not improve from 0.89655
#
# Epoch 00913: val_accuracy did not improve from 0.89655
#
# Epoch 00914: val_accuracy did not improve from 0.89655
#
# Epoch 00915: val_accuracy did not improve from 0.89655
#
# Epoch 00916: val_accuracy did not improve from 0.89655
#
# Epoch 00917: val_accuracy did not improve from 0.89655
#
# Epoch 00918: val_accuracy did not improve from 0.89655
#
# Epoch 00919: val_accuracy did not improve from 0.89655
#
# Epoch 00920: val_accuracy did not improve from 0.89655
#
# Epoch 00921: val_accuracy did not improve from 0.89655
#
# Epoch 00922: val_accuracy did not improve from 0.89655
#
# Epoch 00923: val_accuracy did not improve from 0.89655
#
# Epoch 00924: val_accuracy did not improve from 0.89655
#
# Epoch 00925: val_accuracy did not improve from 0.89655
#
# Epoch 00926: val_accuracy did not improve from 0.89655
#
# Epoch 00927: val_accuracy did not improve from 0.89655
#
# Epoch 00928: val_accuracy did not improve from 0.89655
#
# Epoch 00929: val_accuracy did not improve from 0.89655
#
# Epoch 00930: val_accuracy did not improve from 0.89655
#
# Epoch 00931: val_accuracy did not improve from 0.89655
#
# Epoch 00932: val_accuracy did not improve from 0.89655
#
# Epoch 00933: val_accuracy did not improve from 0.89655
#
# Epoch 00934: val_accuracy did not improve from 0.89655
#
# Epoch 00935: val_accuracy did not improve from 0.89655
#
# Epoch 00936: val_accuracy did not improve from 0.89655
#
# Epoch 00937: val_accuracy did not improve from 0.89655
#
# Epoch 00938: val_accuracy did not improve from 0.89655
#
# Epoch 00939: val_accuracy did not improve from 0.89655
#
# Epoch 00940: val_accuracy did not improve from 0.89655
#
# Epoch 00941: val_accuracy did not improve from 0.89655
#
# Epoch 00942: val_accuracy did not improve from 0.89655
#
# Epoch 00943: val_accuracy did not improve from 0.89655
#
# Epoch 00944: val_accuracy did not improve from 0.89655
#
# Epoch 00945: val_accuracy did not improve from 0.89655
#
# Epoch 00946: val_accuracy did not improve from 0.89655
#
# Epoch 00947: val_accuracy did not improve from 0.89655
#
# Epoch 00948: val_accuracy did not improve from 0.89655
#
# Epoch 00949: val_accuracy did not improve from 0.89655
#
# Epoch 00950: val_accuracy did not improve from 0.89655
#
# Epoch 00951: val_accuracy did not improve from 0.89655
#
# Epoch 00952: val_accuracy did not improve from 0.89655
#
# Epoch 00953: val_accuracy did not improve from 0.89655
#
# Epoch 00954: val_accuracy did not improve from 0.89655
#
# Epoch 00955: val_accuracy did not improve from 0.89655
#
# Epoch 00956: val_accuracy did not improve from 0.89655
#
# Epoch 00957: val_accuracy did not improve from 0.89655
#
# Epoch 00958: val_accuracy did not improve from 0.89655
#
# Epoch 00959: val_accuracy did not improve from 0.89655
#
# Epoch 00960: val_accuracy did not improve from 0.89655
#
# Epoch 00961: val_accuracy did not improve from 0.89655
#
# Epoch 00962: val_accuracy did not improve from 0.89655
#
# Epoch 00963: val_accuracy did not improve from 0.89655
#
# Epoch 00964: val_accuracy did not improve from 0.89655
#
# Epoch 00965: val_accuracy did not improve from 0.89655
#
# Epoch 00966: val_accuracy did not improve from 0.89655
#
# Epoch 00967: val_accuracy did not improve from 0.89655
#
# Epoch 00968: val_accuracy did not improve from 0.89655
#
# Epoch 00969: val_accuracy did not improve from 0.89655
#
# Epoch 00970: val_accuracy did not improve from 0.89655
#
# Epoch 00971: val_accuracy did not improve from 0.89655
#
# Epoch 00972: val_accuracy did not improve from 0.89655
#
# Epoch 00973: val_accuracy did not improve from 0.89655
#
# Epoch 00974: val_accuracy did not improve from 0.89655
#
# Epoch 00975: val_accuracy did not improve from 0.89655
#
# Epoch 00976: val_accuracy did not improve from 0.89655
#
# Epoch 00977: val_accuracy did not improve from 0.89655
#
# Epoch 00978: val_accuracy did not improve from 0.89655
#
# Epoch 00979: val_accuracy did not improve from 0.89655
#
# Epoch 00980: val_accuracy did not improve from 0.89655
#
# Epoch 00981: val_accuracy did not improve from 0.89655
#
# Epoch 00982: val_accuracy did not improve from 0.89655
#
# Epoch 00983: val_accuracy did not improve from 0.89655
#
# Epoch 00984: val_accuracy did not improve from 0.89655
#
# Epoch 00985: val_accuracy did not improve from 0.89655
#
# Epoch 00986: val_accuracy did not improve from 0.89655
#
# Epoch 00987: val_accuracy did not improve from 0.89655
#
# Epoch 00988: val_accuracy did not improve from 0.89655
#
# Epoch 00989: val_accuracy did not improve from 0.89655
#
# Epoch 00990: val_accuracy did not improve from 0.89655
#
# Epoch 00991: val_accuracy did not improve from 0.89655
#
# Epoch 00992: val_accuracy did not improve from 0.89655
#
# Epoch 00993: val_accuracy did not improve from 0.89655
#
# Epoch 00994: val_accuracy did not improve from 0.89655
#
# Epoch 00995: val_accuracy did not improve from 0.89655
#
# Epoch 00996: val_accuracy did not improve from 0.89655
#
# Epoch 00997: val_accuracy did not improve from 0.89655
#
# Epoch 00998: val_accuracy did not improve from 0.89655
#
# Epoch 00999: val_accuracy did not improve from 0.89655
#
# Epoch 01000: val_accuracy did not improve from 0.89655
# loss:  1.1431338682509304
# accuracy:  0.6491228342056274
# kappa:  0.5331695331695332
# confusion matrix:
#  [[ 9  5  1  0]
#  [ 0 10  3  1]
#  [ 0  6  7  1]
#  [ 0  2  1 11]]
# Resultados:
# loss: [1.1046854093157012, 0.8204250685099898, 0.8417689718049148, 0.9951082961312656, 1.3399216635473843, 0.39822186889319583, 0.5084038199039927, 0.8262389699618021, 0.6848742763201395, 1.1431338682509304]
# accuracy: [0.6551724076271057, 0.7586206793785095, 0.6896551847457886, 0.7068965435028076, 0.5862069129943848, 0.7931034564971924, 0.8245614171028137, 0.7368420958518982, 0.7543859481811523, 0.6491228342056274]
# kappa: [0.5387673956262425, 0.6777777777777778, 0.5858786195953987, 0.6085748312822549, 0.4478381594605316, 0.7242472266244058, 0.7658175842235004, 0.650163666121113, 0.6725482150184653, 0.5331695331695332]
# Tiempo: 2669.217932701111

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 264, 8, 16)        160
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 132, 4, 16)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 132, 4, 16)        2320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 66, 2, 16)         0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 2112)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               270464
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 273,460
# Trainable params: 273,460
# Non-trainable params: 0
# _________________________________________________________________

# %%
print("Mean Accuracy: %.4f" % np.mean(array_acc))
print("std: (+/- %.4f)" % np.std(array_acc))
print("Mean Kappa: %.4f" % np.mean(array_kappa))
print("std: (+/- %.4f)" % np.std(array_kappa))
print("Max Accuracy: %.4f" % np.max(array_acc))
print("Max Kappa: %.4f" % np.max(array_kappa))
# Out:
# Mean Accuracy: 0.7155
# std: (+/- 0.0687)
# Mean Kappa: 0.6205
# std: (+/- 0.0918)
# Max Accuracy: 0.8246
# Max Kappa: 0.7658

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Mon May 18 21:50:22 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    32W / 250W |   1139MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
